# %% [markdown]
# <a href="https://colab.research.google.com/github/pondbaahh/data_viz_2022/blob/main/Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Final Project
# ทำ Dashboard ของ Data Covid (ตั้งแต่วันที่ 12/01/2020 - 18/03/2022) เล่ามุมมองที่เราเลือกเอง + ใช้ข้อมูลภูมิภาค + ข้อมูลอื่นที่เลือกเอง

# %% [markdown]
# ###เตรียมข้อมูล

# %% [markdown]
# ####Import data

# %%
import pandas as pd  # เรียกใช้คำว่า pd แทน pandas ได้
import os

# %%
from google.colab import drive  # pandas ใช้จัดการไฟล์ต่าง ๆ ที่เป็นตาราง เช่น excel .csv
drive.mount('/content/drive') # ถ้าไฟล์ใน gg drive ไม่หาย ก็จะยังสามารถรันข้อมูลได้
path = '/content/drive/My Drive/project_dataviz'
# Out:
# Mounted at /content/drive

# %%
data_covid1 = pd.read_csv(os.path.join(path, 'confirmed-cases.csv'))
data_covid2 = pd.read_csv(os.path.join(path, 'confirmed-cases-since-120864.csv'))
data_covid3 = pd.read_csv(os.path.join(path, 'confirmed-cases-since-271064.csv'))
data_covid4 = pd.read_csv(os.path.join(path, 'confirmed-cases-since-280265.csv'))
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ###confirmed-cases 1
# ข้อมูล confirmed-cases ตั้งแต่วันแรก - 11/08/2021

# %%
data_covid1
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 816984  816985     11/8/2021     10/8/2021  หญิง   8.0   ปี    Thailand
# 816985  816986     11/8/2021     10/8/2021   ชาย  14.0   ปี    Thailand
# 816986  816987     11/8/2021     10/8/2021   ชาย  59.0   ปี    Thailand
# 816987  816988     11/8/2021     10/8/2021  หญิง  34.0   ปี    Thailand
# 816988  816989     11/8/2021     10/8/2021  หญิง  19.0   ปี    Thailand
#
#        province_of_isolation  \
# 0              กรุงเทพมหานคร
# 1              กรุงเทพมหานคร
# 2                     นครปฐม
# 3              กรุงเทพมหานคร
# 4                    นนทบุรี
# ...                      ...
# 816984               สระแก้ว
# 816985               สระแก้ว
# 816986               สระแก้ว
# 816987               สระแก้ว
# 816988               สระแก้ว
#
#                                                      risk province_of_onset  \
# 0                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2                        คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...                                                   ...               ...
# 816984                               อยู่ระหว่างการสอบสวน           สระแก้ว
# 816985                               อยู่ระหว่างการสอบสวน           สระแก้ว
# 816986  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...           สระแก้ว
# 816987                                              อื่นๆ     กรุงเทพมหานคร
# 816988                                              อื่นๆ   พระนครศรีอยุธยา
#
#        district_of_onset
# 0                    NaN
# 1                    NaN
# 2                  เมือง
# 3                    NaN
# 4                    NaN
# ...                  ...
# 816984           ตาพระยา
# 816985           ตาพระยา
# 816986        อรัญประเทศ
# 816987       บางขุนเทียน
# 816988             อุทัย
#
# [816989 rows x 11 columns]

# %% [markdown]
# ###ตรวจสอบ Missing

# %%
data_covid1.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# ###แทน missing ด้วยค่าที่เหมาะสม (fillna())

# %%
data_covid1_updated = data_covid1.fillna(value={'Notified date':'ไม่มีข้อมูล','sex':'ไม่มีข้อมูล','Unit':'ไม่มีข้อมูล','nationality':'ไม่มีข้อมูล','province_of_isolation':'ไม่มีข้อมูล','risk':'ไม่มีข้อมูล','province_of_onset':'ไม่มีข้อมูล','district_of_onset':'ไม่มีข้อมูล'})  # เลข -99 คือการใสเลขที่ไม่ซ้ำจากอันเดิม  #ตัวแปรชื่อ value  #แทนค่า missing ด้วย 'ไม่รู้'
data_covid1_updated.head()
# Out:
#    No. announce_date Notified date   sex   age Unit nationality  \
# 0    1     12/1/2020   ไม่มีข้อมูล  หญิง  61.0   ปี       China
# 1    2     17/1/2020   ไม่มีข้อมูล  หญิง  74.0   ปี       China
# 2    3     22/1/2020   ไม่มีข้อมูล  หญิง  73.0   ปี    Thailand
# 3    4     22/1/2020   ไม่มีข้อมูล   ชาย  68.0   ปี       China
# 4    5     24/1/2020   ไม่มีข้อมูล  หญิง  66.0   ปี       China
#
#   province_of_isolation                              risk province_of_onset  \
# 0         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2                นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4               นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
#
#   district_of_onset
# 0       ไม่มีข้อมูล
# 1       ไม่มีข้อมูล
# 2             เมือง
# 3       ไม่มีข้อมูล
# 4       ไม่มีข้อมูล

# %%
data_covid1_updated.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                       True
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %% [markdown]
# ###แทน age ด้วยค่า mean

# %%
data_covid_mean1 = data_covid1_updated.fillna(value={'age':data_covid1['age'].mean()})  #เติม missing ด้วยค่าเฉลี่ย

# %%
data_covid_mean1.isnull().any()  #คอลัมน์ sex ไม่มี missing
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %%
data_covid_mean1
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020   ไม่มีข้อมูล  หญิง  61.0   ปี       China
# 1            2     17/1/2020   ไม่มีข้อมูล  หญิง  74.0   ปี       China
# 2            3     22/1/2020   ไม่มีข้อมูล  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020   ไม่มีข้อมูล   ชาย  68.0   ปี       China
# 4            5     24/1/2020   ไม่มีข้อมูล  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 816984  816985     11/8/2021     10/8/2021  หญิง   8.0   ปี    Thailand
# 816985  816986     11/8/2021     10/8/2021   ชาย  14.0   ปี    Thailand
# 816986  816987     11/8/2021     10/8/2021   ชาย  59.0   ปี    Thailand
# 816987  816988     11/8/2021     10/8/2021  หญิง  34.0   ปี    Thailand
# 816988  816989     11/8/2021     10/8/2021  หญิง  19.0   ปี    Thailand
#
#        province_of_isolation  \
# 0              กรุงเทพมหานคร
# 1              กรุงเทพมหานคร
# 2                     นครปฐม
# 3              กรุงเทพมหานคร
# 4                    นนทบุรี
# ...                      ...
# 816984               สระแก้ว
# 816985               สระแก้ว
# 816986               สระแก้ว
# 816987               สระแก้ว
# 816988               สระแก้ว
#
#                                                      risk province_of_onset  \
# 0                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2                        คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4                        คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...                                                   ...               ...
# 816984                               อยู่ระหว่างการสอบสวน           สระแก้ว
# 816985                               อยู่ระหว่างการสอบสวน           สระแก้ว
# 816986  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...           สระแก้ว
# 816987                                              อื่นๆ     กรุงเทพมหานคร
# 816988                                              อื่นๆ   พระนครศรีอยุธยา
#
#        district_of_onset
# 0            ไม่มีข้อมูล
# 1            ไม่มีข้อมูล
# 2                  เมือง
# 3            ไม่มีข้อมูล
# 4            ไม่มีข้อมูล
# ...                  ...
# 816984           ตาพระยา
# 816985           ตาพระยา
# 816986        อรัญประเทศ
# 816987       บางขุนเทียน
# 816988             อุทัย
#
# [816989 rows x 11 columns]

# %% [markdown]
# ###confirmed-cases 2
# ตั้งแต่วันที่ 12/08/2021 - วันที่ 25/10/2021

# %%
data_covid2
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0         816990     12/8/2021     11/8/2021   ชาย   7.0   ปี    Thailand
# 1         816991     12/8/2021     11/8/2021   ชาย   1.0   ปี    Thailand
# 2         816992     12/8/2021     11/8/2021   ชาย  35.0   ปี    Thailand
# 3         816993     12/8/2021     11/8/2021  หญิง  33.0   ปี    Thailand
# 4         816994     12/8/2021     11/8/2021  หญิง  14.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1042163  1859153    25/10/2021    24/10/2021   ชาย  45.0   ปี         NaN
# 1042164  1859154    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042165  1859155    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042166  1859156    25/10/2021    24/10/2021   ชาย  24.0   ปี         NaN
# 1042167  1859157    25/10/2021    24/10/2021   ชาย  25.0   ปี         NaN
#
#         province_of_isolation                                         risk  \
# 0                    เชียงราย                                        อื่นๆ
# 1                    เชียงราย                                        อื่นๆ
# 2                    เชียงราย                                        อื่นๆ
# 3                    เชียงราย                                        อื่นๆ
# 4                    เชียงราย  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                          ...
# 1042163         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042164         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042165         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042166         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042167             เชียงใหม่                             ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset
# 0                     NaN               NaN
# 1                     NaN               NaN
# 2                     NaN               NaN
# 3                     NaN               NaN
# 4                     NaN               NaN
# ...                   ...               ...
# 1042163               NaN               NaN
# 1042164               NaN               NaN
# 1042165               NaN               NaN
# 1042166               NaN               NaN
# 1042167               NaN               NaN
#
# [1042168 rows x 11 columns]

# %% [markdown]
# ###ตรวจสอบ Missing

# %%
data_covid2.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation    False
# risk                     False
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# ###แทน missing ด้วยค่าที่เหมาะสม (fillna())

# %%
data_covid2_updated = data_covid2.fillna(value={'sex':'ไม่มีข้อมูล','Unit':'ไม่มีข้อมูล','nationality':'ไม่มีข้อมูล','province_of_onset':'ไม่มีข้อมูล','district_of_onset':'ไม่มีข้อมูล'})  # เลข -99 คือการใสเลขที่ไม่ซ้ำจากอันเดิม  #ตัวแปรชื่อ value  #แทนค่า missing ด้วย 'ไม่รู้'
data_covid2_updated.head()
# Out:
#       No. announce_date Notified date   sex   age Unit nationality  \
# 0  816990     12/8/2021     11/8/2021   ชาย   7.0   ปี    Thailand
# 1  816991     12/8/2021     11/8/2021   ชาย   1.0   ปี    Thailand
# 2  816992     12/8/2021     11/8/2021   ชาย  35.0   ปี    Thailand
# 3  816993     12/8/2021     11/8/2021  หญิง  33.0   ปี    Thailand
# 4  816994     12/8/2021     11/8/2021  หญิง  14.0   ปี    Thailand
#
#   province_of_isolation                                         risk  \
# 0              เชียงราย                                        อื่นๆ
# 1              เชียงราย                                        อื่นๆ
# 2              เชียงราย                                        อื่นๆ
# 3              เชียงราย                                        อื่นๆ
# 4              เชียงราย  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
#   province_of_onset district_of_onset
# 0       ไม่มีข้อมูล       ไม่มีข้อมูล
# 1       ไม่มีข้อมูล       ไม่มีข้อมูล
# 2       ไม่มีข้อมูล       ไม่มีข้อมูล
# 3       ไม่มีข้อมูล       ไม่มีข้อมูล
# 4       ไม่มีข้อมูล       ไม่มีข้อมูล

# %% [markdown]
# ###แทน age ด้วยค่า mean

# %%
data_covid_mean2 = data_covid2_updated .fillna(value={'age':data_covid1['age'].mean()})  #เติม missing ด้วยค่าเฉลี่ย

# %%
data_covid_mean2.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %%
data_covid_mean2
# Out:
#              No. announce_date Notified date   sex   age Unit  nationality  \
# 0         816990     12/8/2021     11/8/2021   ชาย   7.0   ปี     Thailand
# 1         816991     12/8/2021     11/8/2021   ชาย   1.0   ปี     Thailand
# 2         816992     12/8/2021     11/8/2021   ชาย  35.0   ปี     Thailand
# 3         816993     12/8/2021     11/8/2021  หญิง  33.0   ปี     Thailand
# 4         816994     12/8/2021     11/8/2021  หญิง  14.0   ปี     Thailand
# ...          ...           ...           ...   ...   ...  ...          ...
# 1042163  1859153    25/10/2021    24/10/2021   ชาย  45.0   ปี  ไม่มีข้อมูล
# 1042164  1859154    25/10/2021    24/10/2021   ชาย  31.0   ปี  ไม่มีข้อมูล
# 1042165  1859155    25/10/2021    24/10/2021   ชาย  31.0   ปี  ไม่มีข้อมูล
# 1042166  1859156    25/10/2021    24/10/2021   ชาย  24.0   ปี  ไม่มีข้อมูล
# 1042167  1859157    25/10/2021    24/10/2021   ชาย  25.0   ปี  ไม่มีข้อมูล
#
#         province_of_isolation                                         risk  \
# 0                    เชียงราย                                        อื่นๆ
# 1                    เชียงราย                                        อื่นๆ
# 2                    เชียงราย                                        อื่นๆ
# 3                    เชียงราย                                        อื่นๆ
# 4                    เชียงราย  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                          ...
# 1042163         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042164         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042165         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042166         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042167             เชียงใหม่                             ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset
# 0             ไม่มีข้อมูล       ไม่มีข้อมูล
# 1             ไม่มีข้อมูล       ไม่มีข้อมูล
# 2             ไม่มีข้อมูล       ไม่มีข้อมูล
# 3             ไม่มีข้อมูล       ไม่มีข้อมูล
# 4             ไม่มีข้อมูล       ไม่มีข้อมูล
# ...                   ...               ...
# 1042163       ไม่มีข้อมูล       ไม่มีข้อมูล
# 1042164       ไม่มีข้อมูล       ไม่มีข้อมูล
# 1042165       ไม่มีข้อมูล       ไม่มีข้อมูล
# 1042166       ไม่มีข้อมูล       ไม่มีข้อมูล
# 1042167       ไม่มีข้อมูล       ไม่มีข้อมูล
#
# [1042168 rows x 11 columns]

# %% [markdown]
# ###confirmed-cases 3
# ตั้งแต่วันที่ 26/10/2021 - วันที่ 27/02/2022

# %%
data_covid3
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0        1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1        1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
# 2        1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี    Thailand
# 3        1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี    Thailand
# 4        1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1010454  2869612     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010455  2869613     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010456  2869614     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010457  2869615     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010458  2869616     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
#
#         province_of_isolation                                           risk  \
# 0                       ลำปาง                                          อื่นๆ
# 1                       ลำปาง                                          อื่นๆ
# 2                       ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 3                       ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 4                       ลำปาง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                            ...
# 1010454         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 1010455         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 1010456               ปัตตานี                               ทัณฑสถาน/เรือนจำ
# 1010457               ปัตตานี                               ทัณฑสถาน/เรือนจำ
# 1010458               ปัตตานี                               ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset  Unnamed: 11
# 0                   ลำปาง        เมืองลำปาง          NaN
# 1                   ลำปาง        เมืองลำปาง          NaN
# 2                   ลำปาง          ห้างฉัตร          NaN
# 3                   ลำปาง          ห้างฉัตร          NaN
# 4                   ลำปาง        เมืองลำปาง          NaN
# ...                   ...               ...          ...
# 1010454               NaN               NaN          NaN
# 1010455               NaN               NaN          NaN
# 1010456               NaN               NaN          NaN
# 1010457               NaN               NaN          NaN
# 1010458               NaN               NaN          NaN
#
# [1010459 rows x 12 columns]

# %% [markdown]
# ###ตรวจสอบ Missing

# %%
data_covid3.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# Unnamed: 11               True
# dtype: bool

# %% [markdown]
# จะเห็นได้ว่า ข้อมูล data_covid3 ยังมีค่า Missing อยู่

# %% [markdown]
# ###แทน missing ด้วยค่าที่เหมาะสม (fillna())

# %%
data_covid3_updated = data_covid3.fillna(value={'sex':'ไม่มีข้อมูล','Unit':'ไม่มีข้อมูล','nationality':'ไม่มีข้อมูล','province_of_isolation':'ไม่มีข้อมูล','risk':'ไม่มีข้อมูล','province_of_onset':'ไม่มีข้อมูล','district_of_onset':'ไม่มีข้อมูล','Unnamed: 11':'ไม่มีข้อมูล'})  # เลข -99 คือการใสเลขที่ไม่ซ้ำจากอันเดิม  #ตัวแปรชื่อ value  #แทนค่า missing ด้วย 'ไม่รู้'
data_covid3_updated.head()
# Out:
#        No. announce_date Notified date   sex   age Unit nationality  \
# 0  1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1  1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
# 2  1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี    Thailand
# 3  1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี    Thailand
# 4  1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี    Thailand
#
#   province_of_isolation                                           risk  \
# 0                 ลำปาง                                          อื่นๆ
# 1                 ลำปาง                                          อื่นๆ
# 2                 ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 3                 ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 4                 ลำปาง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
#   province_of_onset district_of_onset  Unnamed: 11
# 0             ลำปาง        เมืองลำปาง  ไม่มีข้อมูล
# 1             ลำปาง        เมืองลำปาง  ไม่มีข้อมูล
# 2             ลำปาง          ห้างฉัตร  ไม่มีข้อมูล
# 3             ลำปาง          ห้างฉัตร  ไม่มีข้อมูล
# 4             ลำปาง        เมืองลำปาง  ไม่มีข้อมูล

# %% [markdown]
# ###แทน age ด้วยค่า mean

# %%
data_covid_mean3 = data_covid3_updated .fillna(value={'age':data_covid1['age'].mean()})  #เติม missing ด้วยค่าเฉลี่ย

# %%
data_covid_mean3.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# Unnamed: 11              False
# dtype: bool

# %%
data_covid_mean3
# Out:
#              No. announce_date Notified date   sex       age         Unit  \
# 0        1859158    26/10/2021    25/10/2021   ชาย      20.0           ปี
# 1        1859159    26/10/2021    25/10/2021  หญิง      42.0           ปี
# 2        1859160    26/10/2021    25/10/2021  หญิง      33.0           ปี
# 3        1859161    26/10/2021    25/10/2021  หญิง      52.0           ปี
# 4        1859162    26/10/2021    25/10/2021  หญิง      84.0           ปี
# ...          ...           ...           ...   ...       ...          ...
# 1010454  2869612     27/2/2022     26/2/2022   ชาย  35.67704  ไม่มีข้อมูล
# 1010455  2869613     27/2/2022     26/2/2022   ชาย  35.67704  ไม่มีข้อมูล
# 1010456  2869614     27/2/2022     26/2/2022   ชาย  35.67704  ไม่มีข้อมูล
# 1010457  2869615     27/2/2022     26/2/2022   ชาย  35.67704  ไม่มีข้อมูล
# 1010458  2869616     27/2/2022     26/2/2022   ชาย  35.67704  ไม่มีข้อมูล
#
#          nationality province_of_isolation  \
# 0           Thailand                 ลำปาง
# 1           Thailand                 ลำปาง
# 2           Thailand                 ลำปาง
# 3           Thailand                 ลำปาง
# 4           Thailand                 ลำปาง
# ...              ...                   ...
# 1010454  ไม่มีข้อมูล         กรุงเทพมหานคร
# 1010455  ไม่มีข้อมูล         กรุงเทพมหานคร
# 1010456  ไม่มีข้อมูล               ปัตตานี
# 1010457  ไม่มีข้อมูล               ปัตตานี
# 1010458  ไม่มีข้อมูล               ปัตตานี
#
#                                                   risk province_of_onset  \
# 0                                                อื่นๆ             ลำปาง
# 1                                                อื่นๆ             ลำปาง
# 2        ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว             ลำปาง
# 3        ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว             ลำปาง
# 4          สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             ลำปาง
# ...                                                ...               ...
# 1010454                               ทัณฑสถาน/เรือนจำ       ไม่มีข้อมูล
# 1010455                               ทัณฑสถาน/เรือนจำ       ไม่มีข้อมูล
# 1010456                               ทัณฑสถาน/เรือนจำ       ไม่มีข้อมูล
# 1010457                               ทัณฑสถาน/เรือนจำ       ไม่มีข้อมูล
# 1010458                               ทัณฑสถาน/เรือนจำ       ไม่มีข้อมูล
#
#         district_of_onset  Unnamed: 11
# 0              เมืองลำปาง  ไม่มีข้อมูล
# 1              เมืองลำปาง  ไม่มีข้อมูล
# 2                ห้างฉัตร  ไม่มีข้อมูล
# 3                ห้างฉัตร  ไม่มีข้อมูล
# 4              เมืองลำปาง  ไม่มีข้อมูล
# ...                   ...          ...
# 1010454       ไม่มีข้อมูล  ไม่มีข้อมูล
# 1010455       ไม่มีข้อมูล  ไม่มีข้อมูล
# 1010456       ไม่มีข้อมูล  ไม่มีข้อมูล
# 1010457       ไม่มีข้อมูล  ไม่มีข้อมูล
# 1010458       ไม่มีข้อมูล  ไม่มีข้อมูล
#
# [1010459 rows x 12 columns]

# %% [markdown]
# ###confirmed-cases 4
# ตั้งแต่วันที่ 26/10/2021 - วันที่ 27/02/2022

# %%
data_covid4
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี    Thailand
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี    Thailand
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.0   ปี    Thailand
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.0   ปี    Thailand
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# 0                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 3                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 4                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                      ...                                          ...
# 433548         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433549         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433550         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433551                 สงขลา                             ทัณฑสถาน/เรือนจำ
# 433552                 สงขลา                             ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0                  พะเยา        เมืองพะเยา
# 1                  พะเยา        เมืองพะเยา
# 2                  พะเยา        เมืองพะเยา
# 3                  พะเยา        เมืองพะเยา
# 4                  พะเยา        เมืองพะเยา
# ...                  ...               ...
# 433548               NaN               NaN
# 433549               NaN               NaN
# 433550               NaN               NaN
# 433551               NaN               NaN
# 433552               NaN               NaN
#
# [433553 rows x 11 columns]

# %% [markdown]
# ###ตรวจสอบ Missing

# %%
data_covid4.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation    False
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# จะเห็นได้ว่า ข้อมูล data_covid2 ยังมีค่า Missing อยู่

# %% [markdown]
# ###แทน missing ด้วยค่าที่เหมาะสม (fillna())

# %%
data_covid4_updated = data_covid4.fillna(value={'sex':'ไม่มีข้อมูล','Unit':'ไม่มีข้อมูล','nationality':'ไม่มีข้อมูล','risk':'ไม่มีข้อมูล','province_of_onset':'ไม่มีข้อมูล','district_of_onset':'ไม่มีข้อมูล'})  
data_covid4_updated.head()
# Out:
#        No. announce_date Notified date   sex   age Unit nationality  \
# 0  2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี    Thailand
# 1  2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี    Thailand
# 2  2869619     28/2/2022     27/2/2022  หญิง  40.0   ปี    Thailand
# 3  2869620     28/2/2022     27/2/2022   ชาย  44.0   ปี    Thailand
# 4  2869621     28/2/2022     27/2/2022   ชาย  11.0   ปี    Thailand
#
#   province_of_isolation                                         risk  \
# 0                 พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1                 พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2                 พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 3                 พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 4                 พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
#   province_of_onset district_of_onset
# 0             พะเยา        เมืองพะเยา
# 1             พะเยา        เมืองพะเยา
# 2             พะเยา        เมืองพะเยา
# 3             พะเยา        เมืองพะเยา
# 4             พะเยา        เมืองพะเยา

# %% [markdown]
# ###แทน age ด้วยค่า mean

# %%
data_covid_mean4 = data_covid4_updated .fillna(value={'age':data_covid1['age'].mean()})  #เติม missing ด้วยค่าเฉลี่ย

# %%
data_covid_mean4.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %% [markdown]
# ข้อมูล data_covid3 ไม่มีค่า missing แล้ว

# %%
data_covid_mean4
# Out:
#             No. announce_date Notified date   sex       age         Unit  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.00000           ปี
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.00000           ปี
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.00000           ปี
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.00000           ปี
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.00000           ปี
# ...         ...           ...           ...   ...       ...          ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง  35.67704  ไม่มีข้อมูล
# 433549  3303166     18/3/2022     17/3/2022  หญิง  35.67704  ไม่มีข้อมูล
# 433550  3303167     18/3/2022     17/3/2022  หญิง  35.67704  ไม่มีข้อมูล
# 433551  3303168     18/3/2022     17/3/2022  หญิง  35.67704  ไม่มีข้อมูล
# 433552  3303169     18/3/2022     17/3/2022  หญิง  35.67704  ไม่มีข้อมูล
#
#         nationality province_of_isolation  \
# 0          Thailand                 พะเยา
# 1          Thailand                 พะเยา
# 2          Thailand                 พะเยา
# 3          Thailand                 พะเยา
# 4          Thailand                 พะเยา
# ...             ...                   ...
# 433548  ไม่มีข้อมูล         กรุงเทพมหานคร
# 433549  ไม่มีข้อมูล         กรุงเทพมหานคร
# 433550  ไม่มีข้อมูล         กรุงเทพมหานคร
# 433551  ไม่มีข้อมูล                 สงขลา
# 433552  ไม่มีข้อมูล                 สงขลา
#
#                                                risk province_of_onset  \
# 0       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 1       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 2       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 3       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# 4       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้             พะเยา
# ...                                             ...               ...
# 433548                             ทัณฑสถาน/เรือนจำ       ไม่มีข้อมูล
# 433549                             ทัณฑสถาน/เรือนจำ       ไม่มีข้อมูล
# 433550                             ทัณฑสถาน/เรือนจำ       ไม่มีข้อมูล
# 433551                             ทัณฑสถาน/เรือนจำ       ไม่มีข้อมูล
# 433552                             ทัณฑสถาน/เรือนจำ       ไม่มีข้อมูล
#
#        district_of_onset
# 0             เมืองพะเยา
# 1             เมืองพะเยา
# 2             เมืองพะเยา
# 3             เมืองพะเยา
# 4             เมืองพะเยา
# ...                  ...
# 433548       ไม่มีข้อมูล
# 433549       ไม่มีข้อมูล
# 433550       ไม่มีข้อมูล
# 433551       ไม่มีข้อมูล
# 433552       ไม่มีข้อมูล
#
# [433553 rows x 11 columns]

# %% [markdown]
# ###แก้ไข้ชื่อจังหวัดใน column province_of_onset

# %%
set(confirm['province_of_onset'])
# Out:
# {'\tประจวบคีรีขันธ์',
#  'USA',
#  '\xa0กาญจนบุรี',
#  '\xa0ชลบุรี',
#  '\xa0ตราด',
#  '\xa0นครปฐม',
#  '\xa0สมุทรสงคราม',
#  '\xa0สมุทรสาคร',
#  '\xa0อุทัยธานี',
#  'กทม',
#  'กทม.',
#  'กบินทร์บุรี',
#  'กระบี่',
#  'กระบี่ี่',
#  'กรุงเทพ',
#  'กรุงเทพมหานคร',
#  'กรุงเทพมหานคร.',
#  'กรุงเทพมหานคร. / พระนครศรีอยุธยา',
#  'กรุงเทพมหานคร. / ศรีสะเกษ',
#  'กรุงเทพฯ',
#  'กะทู้',
#  'กัมพูชา',
#  'กาญจนบุรี',
#  'กาญจบุรี',
#  'กาญนบุรี',
#  'กาฬสิน',
#  'กาฬสินธิ์',
#  'กาฬสินธุ์',
#  'กาฬสินธุ์\xa0',
#  'กาฬสินธ์',
#  'กำเพงเพชร',
#  'กำแพง',
#  'กำแพงเพชร',
#  'กำแพงเพชร\xa0',
#  'กําแพงเพชร',
#  'ขอนแก่น',
#  'ขอนแก่น\xa0',
#  'ขอนแก่่น',
#  'ขัยนาท',
#  'ขัยภูมิ',
#  'ขานุวรลักษณ์บุรี',
#  'คนไทยเดินทางกลับจากต่างประเทศ',
#  'คลองเตย',
#  'จ.กรุงเทพมหานคร',
#  'จ.ภูเก็ต',
#  'จ.ราชบุรี',
#  'จ.สุราษฎร์ธานี',
#  'จังหวัดสมุทรสาคร',
#  'จันทบุรี',
#  'ฉะเชองเทราร',
#  'ฉะเชิงเทรา',
#  'ชมพร',
#  'ชลบุรี',
#  'ชลบุรี\t',
#  'ชลบุรี\xa0',
#  'ชลบุุรี',
#  'ชอนแก่น',
#  'ชัยนาถ',
#  'ชัยนาท',
#  'ชัยบาดาล',
#  'ชัยภูมิ',
#  'ชัยภูมิ\xa0',
#  'ชุมพร',
#  'ชุุมพร',
#  'ชุุุมพร',
#  'ดอนมดแดง',
#  'ดินแดง',
#  'ตรัง',
#  'ตรััง',
#  'ตราด',
#  'ตราด\xa0',
#  'ตาก',
#  'ตากใบ',
#  'ต่างจังหวัด',
#  'ทุ่งเสลี่ยม',
#  'ท้ายบ้าน',
#  'ธารโต',
#  'นคนปฐม',
#  'นคปฐม',
#  'นครนปฐม',
#  'นครนาชสีมา',
#  'นครนายก',
#  'นครปฐม',
#  'นครปฐม\xa0',
#  'นครปบม',
#  'นครพนม',
#  'นครพนม\xa0',
#  'นครยายก',
#  'นครราขสีมา',
#  'นครราชธานี',
#  'นครราชศรีมา',
#  'นครราชสสีมา',
#  'นครราชสีมา',
#  'นครราชสีมา ลพบุรี',
#  'นครราชสีมา\xa0',
#  'นครศรธรรมราช',
#  'นครศรี',
#  'นครศรีธรมมราช',
#  'นครศรีธรมราช',
#  'นครศรีธรรมราข',
#  'นครศรีธรรมราช',
#  'นครศรีฯ',
#  'นครศรีีธรรมราช',
#  'นครศร๊ธรรมราช',
#  'นครศร๊ะรรมราช',
#  'นครสรรค์',
#  'นครสรีธรรมราช',
#  'นครสวรรค',
#  'นครสวรรค์',
#  'นครสวรรค์\xa0',
#  'นครสีธรรมราช',
#  'นครฯ',
#  'นคราชสีมา',
#  'นครีศรีธรรมราช',
#  'นตรนายก',
#  'นตรปฐม',
#  'นนทบุรี',
#  'นนทบุรี\xa0',
#  'นนทบุุรี',
#  'นนทุบรี',
#  'นนทุรี',
#  'นนมบุรี',
#  'นรศรีธรรมราช',
#  'นราธิวาส',
#  'นราธิวาส\u200b',
#  'นราธฺวาส',
#  'นอกเขต',
#  'นาราธิวาส',
#  'นาวัง',
#  'น่าน',
#  'น่าน/ฉะเชิงเทรา',
#  'บางกรวย',
#  'บางกะปิ',
#  'บางนา',
#  'บางปะอิน',
#  'บางละมุง',
#  'บางศรีเมือง',
#  'บางเพียง',
#  'บึงกาฬ',
#  'บึงโขงหลง',
#  'บุรีรัมภ์',
#  'บุรีรัมย์',
#  'บุรีรัมย์\xa0',
#  'บุรีรัยม์',
#  'บุรีรีมย์',
#  'บ้านหลวง',
#  'ปจ',
#  'ปทึมธานี',
#  'ปทุทธานี',
#  'ปทุมฑานี',
#  'ปทุมทานี',
#  'ปทุมธาน',
#  'ปทุมธานี',
#  'ปทุมธานี.',
#  'ปทุมธานี\xa0',
#  'ปทุมธานีี',
#  'ปทุมาธานี',
#  'ปทุุมธานี',
#  'ปธุมธานี',
#  'ปมุมธานี',
#  'ประจวนคีรีขันธ็',
#  'ประจวบ',
#  'ประจวบคิรีขันธ์',
#  'ประจวบคีรขันธ์',
#  'ประจวบคีรขัันธ์',
#  'ประจวบคีรีขัน',
#  'ประจวบคีรีขันธื',
#  'ประจวบคีรีขันธฺ',
#  'ประจวบคีรีขันธ์',
#  'ประจวบคีรีขันธ์\xa0',
#  'ประจวบคีรีขันธ์์',
#  'ประจวบคีรีขัันธ์',
#  'ประจวบคีีรีขันธ์',
#  'ประจวบฯ',
#  'ประทุมธานี',
#  'ประเทศกัมพูชา',
#  'ปราจีนบุรี',
#  'ปราจีบุรี',
#  'ปลวกแดง',
#  'ปลายพระยา',
#  'ปอยเปต',
#  'ปัตตนรี',
#  'ปัตตานนี',
#  'ปัตตานี',
#  'ปัตตานีี',
#  'ปัว',
#  'ปััตตานี',
#  'ปุทมธานี',
#  'ป่าโมก',
#  'พม่า',
#  'พรหมพิราม',
#  'พระนครศรียุธยา',
#  'พระนครศรีอยุทธยา',
#  'พระนครศรีอยุทยา',
#  'พระนครศรีอยุธยา',
#  'พระนครศรีอยุธยา\xa0',
#  'พะเยา',
#  'พังงา',
#  'พัทยา',
#  'พัทลุง',
#  'พัทลุุง',
#  'พัังงา',
#  'พิจิตร',
#  'พิษณุโลก',
#  'พิษณุโลก\xa0',
#  'พิษณูโลก',
#  'ฟินแลนด์',
#  'ภาษีเจริญ',
#  'ภุเก็ต',
#  'ภูุเก็ต',
#  'ภููเก็ต',
#  'ภูเก็ต',
#  'ภูเก็็ต',
#  'ภูเพียง',
#  'มหาสาคาม',
#  'มหาสารคาม',
#  'มาเลเซีย',
#  'มุกดาหาร',
#  'มุกาดหาร',
#  'ยะลา',
#  'ยานนาวา',
#  'ยโสธร',
#  'ร.จ.จ.นราธิวาส',
#  'รอ',
#  'ระนอง',
#  'ระบุ',
#  'ระยอง',
#  'ระยอง\xa0',
#  'ระอยง',
#  'ราชบบุรี',
#  'ราชบุรี',
#  'ราชบุรีี',
#  'ราชบุรี\u200b',
#  'ราชุรี',
#  'ราชเทวี',
#  'ร้องกวาง',
#  'ร้อยเอ็ด',
#  'ลบุรี',
#  'ลพบุรี',
#  'ลพบุรี.',
#  'ลพบุรี\xa0',
#  'ลอง',
#  'ลาดกระบัง',
#  'ลาดพร้าว',
#  'ลาว',
#  'ลำปาง',
#  'ลำพูน',
#  'ลำพูน\u200b',
#  'ลำพููน',
#  'ลำลูกกา',
#  'วังชิ้น',
#  'วังทอง',
#  'วิเศษชัยชาญ',
#  'ศรีษะสะเกษ',
#  'ศรีษะเกษ',
#  'ศรีสระเกษ',
#  'ศรีสะเกษ',
#  'ศีรสะเกษ',
#  'สกลนคร',
#  'สครสวรรค์',
#  'สงขลา',
#  'สงขลา\u200b',
#  'สตูล',
#  'สถานที่ทำงาน',
#  'สพรรณบุรี',
#  'สมถทรปราการ',
#  'สมทรสงคราม',
#  'สมทรสาคร',
#  'สมุครปราการ',
#  'สมุครสาคร',
#  'สมุท',
#  'สมุทปราการ',
#  'สมุทรปรากร',
#  'สมุทรปรากรร',
#  'สมุทรปรากา',
#  'สมุทรปราการ',
#  'สมุทรปราการ\xa0',
#  'สมุทรศาคร',
#  'สมุทรสงคราม',
#  'สมุทรสาคร',
#  'สมุทรสาคร\xa0',
#  'สมุทรสาคา',
#  'สมุทรสาคาร',
#  'สมุทรสาทร',
#  'สมุทรสารคร',
#  'สมุทราปราการ',
#  'สมุทราสาคร',
#  'สมุทสงคราม',
#  'สมุทสาคร',
#  'สมุย',
#  'สมุุทรปราการ',
#  'สมุุทรสงคราม',
#  'สมุุทรสาคร',
#  'สระก้ว',
#  'สระบุรี',
#  'สระบุรี\xa0',
#  'สระแก้ว',
#  'สรินทร์',
#  'สวิสเซอร์แลนด์',
#  'สอง',
#  'สองแคว',
#  'สะพานสูง',
#  'สะแก้ว',
#  'สัตหีบ',
#  'สัมผัสผู้ป่วยยืนยัน COVID20',
#  'สามุทรสาคร',
#  'สารคาม',
#  'สารภี',
#  'สิงห์บุรี',
#  'สิงห์บุรี\xa0',
#  'สุทรปราการ',
#  'สุพรรญบุรี',
#  'สุพรรณบุรั',
#  'สุพรรณบุรี',
#  'สุพรรณบุรี\xa0',
#  'สุมทรปราการ',
#  'สุมทรสาคร',
#  'สุมุทรปราการ',
#  'สุมุทรสาคร',
#  'สุระบุรี',
#  'สุราษ',
#  'สุราษฎณ์ธานี',
#  'สุราษฎธานี',
#  'สุราษฎร์',
#  'สุราษฎร์ธานี',
#  'สุราษฎร์ฯ',
#  'สุราษฎร์์ธานี',
#  'สุราษฎ์ธานี',
#  'สุราษฏร์ธานี',
#  'สุราษธานี',
#  'สุราษร์ฎธานี',
#  'สุราษร์ธานี',
#  'สุราษฯ',
#  'สุรินทรื',
#  'สุรินทร์',
#  'สุรินทร์ 32150',
#  'สุรินทร์,รีสะเกษ',
#  'สุรินทร์\xa0',
#  'สุริมทร์',
#  'สุริะแก้ว',
#  'สุวรรณภูมิ',
#  'สุุพรรณบุรี',
#  'สุุราษฎร์ธานี',
#  'สุุราษฏร์ธานี',
#  'สุุราษฯ',
#  'สุุรินทร์',
#  'สุุุโขทัย',
#  'สุโขทับ',
#  'สุโขทัย',
#  'สุโขทัย\xa0',
#  'สูงเม่น',
#  'หนวงบัวลำภู',
#  'หนองคาย',
#  'หนองงคาย',
#  'หนองบัวภู',
#  'หนองบัวลำพูน',
#  'หนองบัวลำภู',
#  'หนองบัวลําภู',
#  'หนองบััวลำภู',
#  'หนองม่วงไข่',
#  'หนอบัวลำภู',
#  'หลายจังหวัด',
#  'หัวหิน',
#  'ห้วยขวาง',
#  'อยุทธยา',
#  'อยุธยา',
#  'อยุุธยา',
#  'อำนาจเจริญ',
#  'อำนาจเจิญ',
#  'อำนาญเจริญ',
#  'อำนาเจริญ',
#  'อิสราเอล',
#  'อุดธานี',
#  'อุดร',
#  'อุดรธาณี',
#  'อุดรธานี',
#  'อุดรธานี\xa0',
#  'อุดรธานีี',
#  'อุดรราชธานี',
#  'อุตรดิตถ์',
#  'อุตรดิตถ์\xa0',
#  'อุตรดิตถ์์',
#  'อุตรดิษถ์',
#  'อุตรดิิตถ์',
#  'อุตรติดถ์',
#  'อุทัยธานี',
#  'อุทัยานี',
#  'อุบลราขธานี',
#  'อุบลราชธานี',
#  'อุบลราชธานี\xa0',
#  'อุุครดิตถ์',
#  'อุุดรธาน',
#  'อุุดรธานี',
#  'อุุตรดิตถ์',
#  'อุุทัยธานี',
#  'อุุบลราชธานี',
#  'อ่งทอง',
#  'อ่างทอง',
#  'อ่างทอง\xa0',
#  'อํานาจเจริญ',
#  'เชิงเทรา',
#  'เชียงราย',
#  'เชียงใหม่',
#  'เชียรใหญ่',
#  'เชีียงราย',
#  'เชีียงใหม่',
#  'เด่นชัย',
#  'เพขรบุรี',
#  'เพขรบูรณื',
#  'เพขรบูรณ์',
#  'เพชรบุรณ์',
#  'เพชรบุรี',
#  'เพชรบุรึ',
#  'เพชรบุุรี',
#  'เพชรบุูรณ์',
#  'เพชรบูรณ์',
#  'เพชรบูรณ์\xa0',
#  'เพชรบูร์',
#  'เพชรบููรณ์',
#  'เมือง',
#  'เมืองตาก',
#  'เมืองน่าน',
#  'เมืองปัตตานี',
#  'เรือ',
#  'เลย',
#  'เลย\xa0',
#  'เวียงจันทร์',
#  'เวียงสา',
#  'แพร่',
#  'แม่ทะ',
#  'แม่ฮ่องสอน',
#  'แล้วป่วย',
#  'โพธิ์ทอง',
#  'ไชโย',
#  'ไม่มีข้อมูล',
#  'ไม่มีชื่อหอพัก',
#  'ไม่ระบุ'}

# %%
confirm['province_of_onset'].replace({'USA':'ไม่มีข้อมูล','\tประจวบคีรีขันธ์':'ประจวบคีรีขันธ์','\xa0กาญจนบุรี':'กาญจนบุรี','\xa0ชลบุรี':'ชลบุรี','\xa0ตราด':'ตราด','\xa0นครปฐม':'นครปฐม',
                                         '\xa0สมุทรสงคราม':'สมุทรสงคราม','\xa0สมุทรสาคร':'สมุทรสาคร','\xa0อุทัยธานี':'อุทัยธานี','กทม':'กรุงเทพมหานคร','กทม.':'กรุงเทพมหานคร','กบินทร์บุรี':'ปราจีนบุรี','กระบี่ี่':'กระบี่','กรุงเทพ':'กรุงเทพมหานคร',
                                         'กรุงเทพมหานคร.':'กรุงเทพมหานคร','กรุงเทพมหานคร. / พระนครศรีอยุธยา':'กรุงเทพมหานคร','กรุงเทพมหานคร. / ศรีสะเกษ':'กรุงเทพมหานคร','กรุงเทพฯ':'กรุงเทพมหานคร','กะทู้':'ภูเก็ต',
                                         'กัมพูชา':'ไม่มีข้อมูล','กาญจบุรี':'กาญจนบุรี','กาญนบุรี':'กาญจนบุรี','กาฬสิน':'กาฬสินธุ์','กาฬสินธิ์':'กาฬสินธุ์','กาฬสินธุ์\xa0':'กาฬสินธุ์','กาฬสินธ์':'กาฬสินธุ์',
                                         'กำเพงเพชร':'กำแพงเพชร','กำแพง':'กำแพงเพชร','กำแพงเพชร':'กำแพงเพชร','กำแพงเพชร\xa0':'กำแพงเพชร','กําแพงเพชร':'กำแพงเพชร',
                                         'ขอนแก่น\xa0':'ขอนแก่น','ขอนแก่่น':'ขอนแก่น','ขานุวรลักษณ์บุรี':'กำแพงเพชร','คนไทยเดินทางกลับจากต่างประเทศ':'ไม่มีข้อมูล','คลองเตย':'กรุงเทพมหานคร','จ.กรุงเทพมหานคร':'กรุงเทพมหานคร',
                                         'จ.ภูเก็ต':'ภูเก็ต','จ.ราชบุรี':'ราชบุรี','จ.สุราษฎร์ธานี':'สุราษฎร์ธานี','จังหวัดสมุทรสาคร':'สมุทรสาคร','ฉะเชองเทราร':'ฉะเชิงเทรา','ชมพร':'ชุมพร',
                                         'ชลบุรี\t':'ชลบุรี','ชลบุรี\xa0':'ชลบุรี','ชลบุุรี':'ชลบุรี','ชอนแก่น':'ขอนแก่น','ชัยนาถ':'ชัยนาท','ชัยบาดาล':'ลพบุรี','ชัยภูมิ\xa0':'ชัยภูมิ','ชุุมพร':'ชุมพร','ชุุุมพร':'ชุมพร',
                                         'ดอนมดแดง':'อุบลราชธานี','ดินแดง':'กรุงเทพมหานคร','ตรััง':'ตรัง','ตราด\xa0':'ตราด','ตากใบ':'นราธิวาส','ต่างจังหวัด':'ไม่มีข้อมูล','ทุ่งเสลี่ยม':'สุโขทัย',
                                         'ท้ายบ้าน':'สมุทรปราการ','ธารโต':'ยะลา','นคนปฐม':'นครปฐม','นคปฐม':'นครปฐม','นครนปฐม':'นครปฐม','นครนาชสีมา':'นครราชสีมา','นครปฐม\xa0':'นครปฐม',
                                         'นครปบม':'นครปฐม','นครพนม\xa0':'นครพนม','นครยายก':'นครนายก','นครราขสีมา':'นครราชสีมา','นครราชธานี':'นครราชสีมา','นครราชศรีมา':'นครราชสีมา','นครราชสสีมา':'นครราชสีมา',
                                         'นครราชสีมา ลพบุรี':'นครราชสีมา','นครราชสีมา\xa0':'นครราชสีมา','นครศรธรรมราช':'นครศรีธรรมราช','นครศรี':'นครศรีธรรมราช','นครศรีธรมมราช':'นครศรีธรรมราช',
                                         'นครศรีธรมราช':'นครศรีธรรมราช','นครศรีธรรมราข':'นครศรีธรรมราช','นครศรีฯ':'นครศรีธรรมราช','นครศรีีธรรมราช':'นครศรีธรรมราช','นครศร๊ธรรมราช':'นครศรีธรรมราช',
                                         'นครศร๊ะรรมราช':'นครศรีธรรมราช','นครสรรค์':'นครสวรรค์','นครสรีธรรมราช':'นครศรีธรรมราช','นครสวรรค':'นครสวรรค์','นครสวรรค์\xa0':'นครสวรรค์','นครสีธรรมราช':'นครศรีธรรมราช',
                                         'นครฯ':'นครศรีธรรมราช','นคราชสีมา':'นครราชสีมา','นครีศรีธรรมราช':'นครศรีธรรมราช','นตรนายก':'นครนายก','นตรปฐม':'นครปฐม','นนทบุรี\xa0':'นนทบุรี',
                                         'นนทบุุรี':'นนทบุรี','นนทุบรี':'นนทบุรี','นนทุรี':'นนทบุรี','นนมบุรี':'นนทบุรี','นรศรีธรรมราช':'นครศรีธรรมราช','นราธิวาส\u200b':'นราธิวาส','นราธฺวาส':'นราธิวาส','นอกเขต':'ไม่มีข้อมูล',
                                         'นาราธิวาส':'นราธิวาส','นาวัง':'หนองบัวลำภู','น่าน/ฉะเชิงเทรา':'น่าน','บางกรวย':'นนทบุรี','บางกะปิ':'กรุงเทพมหานคร','บางนา':'กรุงเทพมหานคร','บางปะอิน':'กรุงเทพมหานคร',
                                         'บางละมุง':'ชลบุรี','บางศรีเมือง':'นนทบุรี','บางเพียง':'สมุทรปราการ','บึงโขงหลง':'บึงกาฬ','บุรีรัมภ์':'บุรีรัมย์','บุรีรัมย์\xa0':'บุรีรัมย์','บุรีรัยม์':'บุรีรัมย์','บุรีรีมย์':'บุรีรัมย์',
                                         'บ้านหลวง':'น่าน','ปจ':'ไม่มีข้อมูล','ปทึมธานี':'ปทุมธานี','ปทุทธานี':'ปทุมธานี','ปทุมฑานี':'ปทุมธานี','ปทุมทานี':'ปทุมธานี','ปทุมธาน':'ปทุมธานี','ปทุมธานี\xa0':'ปทุมธานี','ปทุมาธานี':'ปทุมธานี',
                                         'ปธุมธานี':'ปทุมธานี','ปทุมธานี.':'ปทุมธานี','ปทุมธานีี':'ปทุมธานี','ปทุุมธานี':'ปทุมธานี','ปมุมธานี':'ปทุมธานี',
                                         'ประจวนคีรีขันธ็':'ประจวบคีรีขันธ์','ประจวบ':'ประจวบคีรีขันธ์','ประจวบคิรีขันธ์':'ประจวบคีรีขันธ์','ประจวบคีรขันธ์':'ประจวบคีรีขันธ์','ประจวบคีรขัันธ์':'ประจวบคีรีขันธ์','ประจวบคีรีขัน':'ประจวบคีรีขันธ์',
                                         'ประจวบคีรีขันธื':'ประจวบคีรีขันธ์','ประจวบคีรีขันธฺ':'ประจวบคีรีขันธ์','ประจวบคีรีขันธ์\xa0':'ประจวบคีรีขันธ์','ประจวบคีรีขันธ์์':'ประจวบคีรีขันธ์','ประจวบคีรีขัันธ์':'ประจวบคีรีขันธ์','ประจวบคีีรีขันธ์':'ประจวบคีรีขันธ์',
                                         'ประจวบฯ':'ประจวบคีรีขันธ์','ประทุมธานี':'ปทุมธานี', 'ประเทศกัมพูชา':'ไม่มีข้อมูล','ปราจีบุรี':'ปราจีนบุรี','ปลวกแดง':'ระยอง','ปลายพระยา':'กระบี่', 'ปอยเปต':'ไม่มีข้อมูล','ปัตตนรี':'ปัตตานี',
                                         'ปัตตานนี':'ปัตตานี','ปัตตานีี':'ปัตตานี','ปัว':'น่าน','ปััตตานี':'ปัตตานี','ปุทมธานี':'ปทุมธานี','ป่าโมก':'อ่างทอง','พม่า':'ไม่มีข้อมูล','พรหมพิราม':'พิษณุโลก','พระนครศรียุธยา':'พระนครศรีอยุธยา',
                                         'พระนครศรีอยุทธยา':'พระนครศรีอยุธยา','พระนครศรีอยุทยา':'พระนครศรีอยุธยา','พระนครศรีอยุธยา\xa0':'พระนครศรีอยุธยา','พัทยา':'ชลบุรี','พัทลุุง':'พัทลุง','พัังงา':'พังงา',
                                         'พิษณุโลก\xa0':'พิษณุโลก','พิษณูโลก':'พิษณุโลก','ฟินแลนด์':'ไม่มีข้อมูล','ภาษีเจริญ':'กรุงเทพมหานคร','ภุเก็ต':'ภูเก็ต','ภูุเก็ต':'ภูเก็ต','ภููเก็ต':'ภูเก็ต','ภูเก็็ต':'ภูเก็ต','ภูเพียง':'น่าน',
                                         'มหาสาคาม':'มหาสารคาม','มาเลเซีย':'ไม่มีข้อมูล','มุกาดหาร':'มุกดาหาร','ยานนาวา':'กรุงเทพมหานคร','ร.จ.จ.นราธิวาส':'นราธิวาส','รอ':'ร้อยเอ็ด','ระบุ':'ไม่มีข้อมูล','ระยอง\xa0':'ระยอง',
                                         'ระอยง':'ระยอง','ราชบบุรี':'ราชบุรี','ราชบุรีี':'ราชบุรี','ราชบุรี\u200b':'ราชบุรี','ราชุรี':'ราชบุรี','ราชเทวี':'กรุงเทพมหานคร','ร้องกวาง':'แพร่','ลบุรี':'ลพบุรี','ลพบุรี.':'ลพบุรี','ลพบุรี\xa0':'ลพบุรี','ลอง':'แพร่',
                                         'ลาดกระบัง':'กรุงเทพมหานคร','ลาดพร้าว':'กรุงเทพมหานคร','ลาว':'ไม่มีข้อมูล','ลำพูน\u200b':'ลำพูน','ลำพููน':'ลำพูน','ลำลูกกา':'ปทุมธานี','วังชิ้น':'ลำปาง','วังทอง':'พิษณุโลก',
                                         'วิเศษชัยชาญ':'อ่างทอง','ศรีษะสะเกษ':'ศรีสะเกษ','ศรีษะเกษ':'ศรีสะเกษ','ศรีสระเกษ':'ศรีสะเกษ','ศีรสะเกษ':'ศรีสะเกษ','สครสวรรค์':'นครสวรรค์',
                                         'สงขลา\u200b':'สงขลา','สถานที่ทำงาน':'ไม่มีข้อมูล','สพรรณบุรี':'สุพรรณบุรี','สมถทรปราการ':'สมุทรปราการ','สมทรสงคราม':'สมุทรสงคราม','สมทรสาคร':'สมุทรสาคร','สมุครปราการ':'สมุทรปราการ',
                                         'สมุครสาคร':'สมุทรสาคร','สมุท':'ไม่มีข้อมูล','สมุทปราการ':'สมุทรปราการ','สมุทรปรากร':'สมุทรปราการ','สมุทรปรากรร':'สมุทรปราการ','สมุทรปราการ\xa0':'สมุทรปราการ','สมุทรศาคร':'สมุทรสาคร',
                                         'สมุทรสาคร\xa0':'สมุทรสาคร','สมุทรสาคา':'สมุทรสาคร','สมุทรสาคาร':'สมุทรสาคร','สมุทรสาทร':'สมุทรสาคร','สมุทรสารคร':'สมุทรสาคร','สมุทราปราการ':'สมุทรปราการ',
                                         'สมุทราสาคร':'สมุทรสาคร','สมุทสงคราม':'สมุทรสงคราม','สมุทสาคร':'สมุทรสาคร','สมุย':'สุราษฎร์ธานี','สมุุทรปราการ':'สมุทรปราการ','สมุุทรสงคราม':'สมุทรสงคราม','สมุุทรสาคร':'สมุทรสาคร',
                                         'สระก้ว':'สระแก้ว','สระบุรี\xa0':'สระบุรี','สรินทร์':'สุรินทร์','สวิสเซอร์แลนด์':'ไม่มีข้อมูล','สอง':'แพร่','สองแคว':'น่าน','สะพานสูง':'กรุงเทพมหานคร',
                                         'สะแก้ว':'สระแก้ว','สัตหีบ':'ชลบุรี','สัมผัสผู้ป่วยยืนยัน COVID20':'ไม่มีข้อมูล','สามุทรสาคร':'สมุทรสาคร','สารคาม':'มหาสารคาม','สารภี':'เชียงใหม่','สิงห์บุรี\xa0':'สิงห์บุรี',
                                         'สุทรปราการ':'สมุทรปราการ','สุพรรญบุรี':'สุพรรณบุรี','สุพรรณบุรั':'สุพรรณบุรี','สุพรรณบุรี\xa0':'สุพรรณบุรี','สุมทรปราการ':'สมุทรปราการ',
                                         'สุมทรสาคร':'สมุทรสาคร','สุมุทรปราการ':'สมุทรปราการ','สุมุทรสาคร':'สมุทรสาคร','สุระบุรี':'สระบุรี','สุราษ':'สุราษฎร์ธานี','สุราษฎณ์ธานี':'สุราษฎร์ธานี','สุราษฎธานี':'สุราษฎร์ธานี',
                                         'สุราษฎร์':'สุราษฎร์ธานี','สุราษฎร์ฯ':'สุราษฎร์ธานี','สุราษฎร์์ธานี':'สุราษฎร์ธานี','สุราษฎ์ธานี':'สุราษฎร์ธานี','สุราษฏร์ธานี':'สุราษฎร์ธานี','สุราษธานี':'สุราษฎร์ธานี',
                                         'สุราษร์ฎธานี':'สุราษฎร์ธานี','สุราษร์ธานี':'สุราษฎร์ธานี','สุราษฯ':'สุราษฎร์ธานี','สุรินทรื':'สุรินทร์','สุรินทร์ 32150':'สุรินทร์','สุรินทร์,รีสะเกษ':'สุรินทร์','สุรินทร์\xa0':'สุรินทร์','สุริมทร์':'สุรินทร์',
                                         'สุริะแก้ว':'สระแก้ว','สุวรรณภูมิ':'สมุทรปราการ','สุุพรรณบุรี':'สุพรรณบุรี','สุุราษฎร์ธานี':'สุราษฎร์ธานี','สุุราษฏร์ธานี':'สุราษฎร์ธนี','สุุราษฯ':'สุราษฎร์ธนี','สุุรินทร์':'สุรินทร์',
                                         'สุุุโขทัย':'สุโขทัย','สุโขทับ':'สุโขทัย','สุโขทัย\xa0':'สุโขทัย','สูงเม่น':'แพร่','หนวงบัวลำภู':'หนองบัวลำภู','หนองงคาย':'หนองคาย','หนองบัวภู':'หนองบัวลำภู',
                                         'หนองบัวลำพูน':'หนองบัวลำภู','หนองบัวลําภู':'หนองบัวลำภู','หนองบััวลำภู':'หนองบัวลำภู','หนองม่วงไข่':'แพร่','หนอบัวลำภู':'หนองบัวลำภู','หลายจังหวัด':'ไม่มีข้อมูล','หัวหิน':'ประจวบคีรีขันธ์',
                                         'ห้วยขวาง':'กรุงเทพมหานคร','อยุทธยา':'พระนครศรีอยุธยา','อยุธยา':'พระนครศรีอยุธยา','อยุุธยา':'พระนครศรีอยุธยา','อำนาจเจิญ':'อำนาจเจริญ','อำนาญเจริญ':'อำนาจเจริญ','อำนาเจริญ':'อำนาจเจริญ',
                                         'อิสราเอล':'ไม่มีข้อมูล','อุดธานี':'อุดรธานี','อุดร':'อุดรธานี','อุดรธาณี':'อุดรธานี','อุดรธานี\xa0':'อุดรธานี','อุดรธานีี':'อุดรธานี','อุดรราชธานี':'อุดรธานี','อุตรดิตถ์\xa0':'อุตรดิตถ์',
                                         'อุตรดิตถ์์':'อุตรดิตถ์','อุตรดิษถ์':'อุตรดิตถ์','อุตรดิิตถ์':'อุตรดิตถ์','อุตรติดถ์':'อุตรดิตถ์','อุบลราขธานี':'อุบลราชธานี','อุบลราชธานี\xa0':'อุบลราชธานี','อุุครดิตถ์':'อุตรดิตถ์',
                                         'อุุดรธาน':'อุดรธานี','อุุดรธานี':'อุดรธานี','อุุตรดิตถ์':'อุตรดิตถ์','อุุทัยธานี':'อุทัยธานี','อุุบลราชธานี':'อุบลราชธานี','อ่งทอง':'อ่างทอง','อ่างทอง\xa0':'อ่างทอง','อํานาจเจริญ':'อำนาจเจริญ',
                                         'เชิงเทรา':'ฉะเชิงเทรา','เชียรใหญ่':'นครศรีธรรมราช','เชีียงราย':'เชียงราย','เชีียงใหม่':'เชียงใหม่','เด่นชัย':'แพร่',
                                         'เพขรบุรี':'เพชรบูรณ์','เพขรบูรณื':'เพชรบูรณ์','เพขรบูรณ์':'เพชรบูรณ์','เพชรบุรณ์':'เพชรบูรณ์','เพชรบุรี':'เพชรบูรณ์','เพชรบุรึ':'เพชรบูรณ์','เพชรบุุรี':'เพชรบูรณ์','เพชรบุูรณ์':'เพชรบูรณ์','เพชรบูรณ์\xa0':'เพชรบูรณ์',
                                         'เพชรบูร์':'เพชรบูรณ์','เพชรบููรณ์':'เพชรบูรณ์','เมือง':'แพร่','เมืองตาก':'ตาก','เมืองน่าน':'น่าน','เมืองปัตตานี':'ปัตตานี','เรือ':'เลย','เลย\xa0':'เลย','เวียงจันทร์':'ไม่มีข้อมูล','เวียงสา':'น่าน','แม่ทะ':'ลำปาง',
                                         'แล้วป่วย':'ไม่มีข้อมูล','โพธิ์ทอง':'อ่างทอง','ไชโย':'อ่างทอง','ไม่มีข้อมูล':'ไม่มีข้อมูล','ไม่มีชื่อหอพัก':'ไม่มีข้อมูล','ไม่ระบุ':'ไม่มีข้อมูล','สมุทรปรากา':'สมุทรปราการ'}, inplace=True)# แก้ไขข้อมูลที่พิมพ์จังหวัดผิด ให้อยู่ในชื่อจังหวัดที่ถูกต้อง

# %%
set(confirm['province_of_onset'])
# Out:
# {'กระบี่',
#  'กรุงเทพมหานคร',
#  'กาญจนบุรี',
#  'กาฬสินธุ์',
#  'กำแพงเพชร',
#  'ขอนแก่น',
#  'ขัยนาท',
#  'ขัยภูมิ',
#  'จันทบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุรี',
#  'ชัยนาท',
#  'ชัยภูมิ',
#  'ชุมพร',
#  'ตรัง',
#  'ตราด',
#  'ตาก',
#  'นครนายก',
#  'นครปฐม',
#  'นครพนม',
#  'นครราชสีมา',
#  'นครศรีธรรมราช',
#  'นครสวรรค์',
#  'นนทบุรี',
#  'นราธิวาส',
#  'น่าน',
#  'บึงกาฬ',
#  'บุรีรัมย์',
#  'ปทุมธานี',
#  'ประจวบคีรีขันธ์',
#  'ปราจีนบุรี',
#  'ปัตตานี',
#  'พระนครศรีอยุธยา',
#  'พะเยา',
#  'พังงา',
#  'พัทลุง',
#  'พิจิตร',
#  'พิษณุโลก',
#  'ภูเก็ต',
#  'มหาสารคาม',
#  'มุกดาหาร',
#  'ยะลา',
#  'ยโสธร',
#  'ระนอง',
#  'ระยอง',
#  'ราชบุรี',
#  'ร้อยเอ็ด',
#  'ลพบุรี',
#  'ลำปาง',
#  'ลำพูน',
#  'ศรีสะเกษ',
#  'สกลนคร',
#  'สงขลา',
#  'สตูล',
#  'สมุทรปราการ',
#  'สมุทรสงคราม',
#  'สมุทรสาคร',
#  'สระบุรี',
#  'สระแก้ว',
#  'สิงห์บุรี',
#  'สุพรรณบุรี',
#  'สุราษฎร์ธนี',
#  'สุราษฎร์ธานี',
#  'สุรินทร์',
#  'สุโขทัย',
#  'หนองคาย',
#  'หนองบัวลำภู',
#  'อำนาจเจริญ',
#  'อุดรธานี',
#  'อุตรดิตถ์',
#  'อุทัยธานี',
#  'อุทัยานี',
#  'อุบลราชธานี',
#  'อ่างทอง',
#  'เชียงราย',
#  'เชียงใหม่',
#  'เพชรบูรณ์',
#  'เลย',
#  'แพร่',
#  'แม่ฮ่องสอน',
#  'ไม่มีข้อมูล'}

# %% [markdown]
# ###ข้อมูลภูมิภาค

# %%
data_province = {'จังหวัด': ['อำนาจเจริญ', 'บึงกาฬ', 'บุรีรัมย์', 'ชัยภูมิ', 'กาฬสินธุ์', 'ขอนแก่น', 'เลย', 'มหาสารคาม', 'มุกดาหาร', 'นครพนม', 'นครราชสีมา', 'หนองบัวลำภู', 'หนองคาย', 'ร้อยเอ็ด', 'สกลนคร', 'ศรีสะเกษ', 'สุรินทร์', 'อุบลราชธานี', 'อุดรธานี', 'ยโสธร','เชียงใหม่', 'เชียงราย', 'ลำปาง', 'ลำพูน', 'แม่ฮ่องสอน', 'น่าน', 'พะเยา', 'แพร่', 'อุตรดิตถ์','ตาก','สุโขทัย', 'พิษณุโลก', 'พิจิตร', 'กำแพงเพชร', 'เพชรบูรณ์','นครสวรรค์', 'อุทัยธานี','อ่างทอง', 'ชัยนาท', 'พระนครศรีอยุธยา', 'กรุงเทพมหานคร', 'ลพบุรี', 'นครปฐม', 'นนทบุรี', 'ปทุมธานี', 'สมุทรปราการ','สมุทรสาคร', 'สมุทรสงคราม','สระบุรี', 'สิงห์บุรี', 'สุพรรณบุรี','นครนายก','ฉะเชิงเทรา', 'จันทบุรี', 'ชลบุรี', 'ปราจีนบุรี', 'ระยอง', 'สระแก้ว', 'ตราด','กาญจนบุรี', 'ราชบุรี','เพชรบุรี', 'ประจวบคีรีขันธ์','ชุมพร', 'นครศรีธรรมราช', 'นราธิวาส', 'ปัตตานี', 'พัทลุง', 'สงขลา', 'สุราษฎร์ธานี', 'ยะลา','กระบี่', 'พังงา', 'ภูเก็ต', 'ระนอง', 'สตูล', 'ตรัง'],
            '6 ภูมิภาค (ภูมิศาสตร์)': ['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','ตะวันตก','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันตก','ตะวันตก','ตะวันตก','ตะวันตก','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้']}

# %%
data6 = pd.DataFrame.from_dict(data_province)
data6
# Out:
#        จังหวัด 6 ภูมิภาค (ภูมิศาสตร์)
# 0   อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 1       บึงกาฬ     ตะวันออกเฉียงเหนือ
# 2    บุรีรัมย์     ตะวันออกเฉียงเหนือ
# 3      ชัยภูมิ     ตะวันออกเฉียงเหนือ
# 4    กาฬสินธุ์     ตะวันออกเฉียงเหนือ
# ..         ...                    ...
# 72       พังงา                    ใต้
# 73      ภูเก็ต                    ใต้
# 74       ระนอง                    ใต้
# 75        สตูล                    ใต้
# 76        ตรัง                    ใต้
#
# [77 rows x 2 columns]

# %% [markdown]
# ###รวมตารางของconfirmed-cases 1 กับ ภูมิภาค

# %%
case_pro1 =  data_covid_mean1 .merge(data6,how='right',left_on='province_of_onset',right_on = 'จังหวัด')
case_pro1
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0          973     26/3/2020     25/3/2020   ชาย  48.0   ปี    Thailand
# 1         1864      2/4/2020      1/4/2020  หญิง  46.0   ปี    Thailand
# 2         6493    30/12/2020    29/12/2020  หญิง  37.0   ปี    Thailand
# 3         7390      3/1/2021      2/1/2021  หญิง  26.0   ปี        Laos
# 4        31038     10/4/2021      9/4/2021   ชาย  38.0   ปี    Thailand
# ...        ...           ...           ...   ...   ...  ...         ...
# 719277  807715     11/8/2021     10/8/2021   ชาย  56.0   ปี    Thailand
# 719278  807716     11/8/2021     10/8/2021   ชาย  31.0   ปี    Thailand
# 719279  807717     11/8/2021     10/8/2021   ชาย  18.0   ปี    Thailand
# 719280  807718     11/8/2021     10/8/2021   ชาย  17.0   ปี    Thailand
# 719281  807719     11/8/2021     10/8/2021   ชาย  50.0   ปี    Thailand
#
#        province_of_isolation                                           risk  \
# 0                 อำนาจเจริญ                                    สถานบันเทิง
# 1                 อำนาจเจริญ                  คนไทยเดินทางกลับจากต่างประเทศ
# 2                 อำนาจเจริญ                                  Cluster ระยอง
# 3                 อำนาจเจริญ    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 4                 อำนาจเจริญ  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# ...                      ...                                            ...
# 719277                  ตรัง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 719278                  ตรัง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 719279                  ตรัง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 719280                  ตรัง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 719281                  ตรัง                                          อื่นๆ
#
#        province_of_onset district_of_onset     จังหวัด 6 ภูมิภาค (ภูมิศาสตร์)
# 0             อำนาจเจริญ             เมือง  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 1             อำนาจเจริญ       ปทุมราชวงศา  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 2             อำนาจเจริญ          หัวตะพาน  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 3             อำนาจเจริญ          หัวตะพาน  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 4             อำนาจเจริญ             เมือง  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# ...                  ...               ...         ...                    ...
# 719277              ตรัง         เมืองตรัง        ตรัง                    ใต้
# 719278              ตรัง         เมืองตรัง        ตรัง                    ใต้
# 719279              ตรัง          หาดสำราญ        ตรัง                    ใต้
# 719280              ตรัง          หาดสำราญ        ตรัง                    ใต้
# 719281              ตรัง           ห้วยยอด        ตรัง                    ใต้
#
# [719282 rows x 13 columns]

# %% [markdown]
# ###รวมตารางของconfirmed-cases 2 กับ ภูมิภาค

# %%
case_pro2 =  data_covid_mean2.merge(data6,how='right',left_on='province_of_onset',right_on = 'จังหวัด')
case_pro2
# Out:
#             No. announce_date Notified date          sex   age Unit  \
# 0        832287     12/8/2021     11/8/2021         หญิง  42.0   ปี
# 1        836816     12/8/2021     11/8/2021  ไม่มีข้อมูล  44.0   ปี
# 2        836825     12/8/2021     11/8/2021  ไม่มีข้อมูล  48.0   ปี
# 3        836942     12/8/2021     11/8/2021  ไม่มีข้อมูล  49.0   ปี
# 4        837015     12/8/2021     11/8/2021  ไม่มีข้อมูล  45.0   ปี
# ...         ...           ...           ...          ...   ...  ...
# 894868  1857091    25/10/2021    24/10/2021         หญิง  33.0   ปี
# 894869  1857092    25/10/2021    24/10/2021         หญิง  36.0   ปี
# 894870  1857093    25/10/2021    24/10/2021         หญิง  48.0   ปี
# 894871  1857094    25/10/2021    24/10/2021         หญิง  45.0   ปี
# 894872  1857095    25/10/2021    24/10/2021          ชาย  22.0   ปี
#
#         nationality province_of_isolation        risk province_of_onset  \
# 0          Thailand            อำนาจเจริญ       อื่นๆ        อำนาจเจริญ
# 1       ไม่มีข้อมูล         กรุงเทพมหานคร  ระบุไม่ได้        อำนาจเจริญ
# 2       ไม่มีข้อมูล         กรุงเทพมหานคร  ระบุไม่ได้        อำนาจเจริญ
# 3       ไม่มีข้อมูล         กรุงเทพมหานคร  ระบุไม่ได้        อำนาจเจริญ
# 4       ไม่มีข้อมูล         กรุงเทพมหานคร  ระบุไม่ได้        อำนาจเจริญ
# ...             ...                   ...         ...               ...
# 894868     Thailand                  ตรัง       อื่นๆ              ตรัง
# 894869     Thailand                  ตรัง       อื่นๆ              ตรัง
# 894870     Thailand                  ตรัง       อื่นๆ              ตรัง
# 894871     Thailand                  ตรัง       อื่นๆ              ตรัง
# 894872     Thailand                  ตรัง       อื่นๆ              ตรัง
#
#        district_of_onset     จังหวัด 6 ภูมิภาค (ภูมิศาสตร์)
# 0               หัวตะพาน  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 1                    พนา  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 2                    พนา  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 3        เมืองอำนาจเจริญ  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 4                    พนา  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# ...                  ...         ...                    ...
# 894868            กันตัง        ตรัง                    ใต้
# 894869            กันตัง        ตรัง                    ใต้
# 894870            กันตัง        ตรัง                    ใต้
# 894871            กันตัง        ตรัง                    ใต้
# 894872            กันตัง        ตรัง                    ใต้
#
# [894873 rows x 13 columns]

# %% [markdown]
# ###รวมตารางของconfirmed-cases 3 กับ ภูมิภาค

# %%
case_pro3 =  data_covid_mean3.merge(data6,how='right',left_on='province_of_onset',right_on = 'จังหวัด')
case_pro3
# Out:
#             No. announce_date Notified date          sex       age  \
# 0       1862512    26/10/2021    25/10/2021         หญิง  35.67704
# 1       1880319    28/10/2021    27/10/2021          ชาย      23.0
# 2       1880320    28/10/2021    27/10/2021          ชาย      26.0
# 3       1883929    28/10/2021    27/10/2021  ไม่มีข้อมูล      50.0
# 4       1900273    30/10/2021    29/10/2021          ชาย      34.0
# ...         ...           ...           ...          ...       ...
# 897889  2866155     27/2/2022     26/2/2022         หญิง      55.0
# 897890  2866156     27/2/2022     26/2/2022          ชาย      34.0
# 897891  2866157     27/2/2022     26/2/2022         หญิง      57.0
# 897892  2866158     27/2/2022     26/2/2022         หญิง      55.0
# 897893  2866159     27/2/2022     26/2/2022         หญิง      67.0
#
#                Unit  nationality province_of_isolation  \
# 0       ไม่มีข้อมูล     Thailand            อำนาจเจริญ
# 1                ปี     Thailand            อำนาจเจริญ
# 2                ปี     Thailand            อำนาจเจริญ
# 3                ปี  ไม่มีข้อมูล         กรุงเทพมหานคร
# 4                ปี     Thailand                 สงขลา
# ...             ...          ...                   ...
# 897889           ปี     Thailand                  ตรัง
# 897890           ปี     Thailand                  ตรัง
# 897891           ปี     Thailand                  ตรัง
# 897892           ปี     Thailand                  ตรัง
# 897893           ปี     Thailand                  ตรัง
#
#                                                risk province_of_onset  \
# 0                   บุคลากรด้านการแพทย์และสาธารณสุข        อำนาจเจริญ
# 1       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้        อำนาจเจริญ
# 2       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้        อำนาจเจริญ
# 3                                             อื่นๆ        อำนาจเจริญ
# 4       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้        อำนาจเจริญ
# ...                                             ...               ...
# 897889                                        อื่นๆ              ตรัง
# 897890                                        อื่นๆ              ตรัง
# 897891  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้              ตรัง
# 897892                                        อื่นๆ              ตรัง
# 897893  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้              ตรัง
#
#        district_of_onset  Unnamed: 11     จังหวัด 6 ภูมิภาค (ภูมิศาสตร์)
# 0                ชานุมาน  ไม่มีข้อมูล  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 1                  เมือง  ไม่มีข้อมูล  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 2                  เมือง  ไม่มีข้อมูล  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 3                ชานุมาน  ไม่มีข้อมูล  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 4               หัวตะพาน  ไม่มีข้อมูล  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# ...                  ...          ...         ...                    ...
# 897889           ห้วยยอด  ไม่มีข้อมูล        ตรัง                    ใต้
# 897890          ปะเหลียน  ไม่มีข้อมูล        ตรัง                    ใต้
# 897891          หาดสำราญ  ไม่มีข้อมูล        ตรัง                    ใต้
# 897892          หาดสำราญ  ไม่มีข้อมูล        ตรัง                    ใต้
# 897893          หาดสำราญ  ไม่มีข้อมูล        ตรัง                    ใต้
#
# [897894 rows x 14 columns]

# %% [markdown]
# ###รวมตารางของconfirmed-cases 4 กับ ภูมิภาค

# %%
case_pro4 =  data_covid_mean4.merge(data6,how='right',left_on='province_of_onset',right_on = 'จังหวัด')
case_pro4
# Out:
#             No. announce_date Notified date          sex       age  \
# 0       2885331     28/2/2022     27/2/2022         หญิง  44.00000
# 1       2885332     28/2/2022     27/2/2022         หญิง  41.00000
# 2       2885334     28/2/2022     27/2/2022          ชาย   4.00000
# 3       2885335     28/2/2022     27/2/2022         หญิง   5.00000
# 4       2885336     28/2/2022     27/2/2022         หญิง  35.00000
# ...         ...           ...           ...          ...       ...
# 387419  3271105     17/3/2022     16/3/2022         หญิง   5.00000
# 387420  3272635     17/3/2022     16/3/2022  ไม่มีข้อมูล  37.00000
# 387421  3293983     18/3/2022     17/3/2022          ชาย  54.00000
# 387422  3297287     18/3/2022     17/3/2022         หญิง  40.00000
# 387423  3300240     18/3/2022     17/3/2022  ไม่มีข้อมูล  35.67704
#
#                Unit  nationality province_of_isolation  \
# 0                ปี     Thailand            อำนาจเจริญ
# 1                ปี     Thailand            อำนาจเจริญ
# 2                ปี     Thailand            อำนาจเจริญ
# 3                ปี     Thailand            อำนาจเจริญ
# 4                ปี     Thailand            อำนาจเจริญ
# ...             ...          ...                   ...
# 387419           ปี     Thailand                  ตรัง
# 387420           ปี  ไม่มีข้อมูล         กรุงเทพมหานคร
# 387421           ปี     Thailand                 ยโสธร
# 387422           ปี     Thailand                ภูเก็ต
# 387423  ไม่มีข้อมูล  ไม่มีข้อมูล         กรุงเทพมหานคร
#
#                                                risk province_of_onset  \
# 0       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้        อำนาจเจริญ
# 1       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้        อำนาจเจริญ
# 2       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้        อำนาจเจริญ
# 3       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้        อำนาจเจริญ
# 4       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้        อำนาจเจริญ
# ...                                             ...               ...
# 387419                                        อื่นๆ              ตรัง
# 387420                                        อื่นๆ              ตรัง
# 387421                                        อื่นๆ              ตรัง
# 387422                                        อื่นๆ              ตรัง
# 387423                                        อื่นๆ              ตรัง
#
#        district_of_onset     จังหวัด 6 ภูมิภาค (ภูมิศาสตร์)
# 0            ปทุมราชวงศา  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 1            ปทุมราชวงศา  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 2            ปทุมราชวงศา  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 3            ปทุมราชวงศา  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 4            ปทุมราชวงศา  อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# ...                  ...         ...                    ...
# 387419         ย่านตาขาว        ตรัง                    ใต้
# 387420         ย่านตาขาว        ตรัง                    ใต้
# 387421       ไม่มีข้อมูล        ตรัง                    ใต้
# 387422             สิเกา        ตรัง                    ใต้
# 387423            กันตัง        ตรัง                    ใต้
#
# [387424 rows x 13 columns]

# %% [markdown]
# ### ข้อมูลความต้องการแรงงาน

# %%
data_Labour = pd.read_csv(os.path.join(path,'Labour-Demand.csv'))
data_Labour
# Out:
#             province  year    month Labour Demand
# 0      กรุงเทพมหานคร  2564   มกราคม         4,763
# 1        สมุทรปราการ  2564   มกราคม           728
# 2            นนทบุรี  2564   มกราคม           525
# 3           ปทุมธานี  2564   มกราคม         1,004
# 4    พระนครศรีอยุธยา  2564   มกราคม           333
# ..               ...   ...      ...           ...
# 919             ตรัง  2564  ธันวาคม            44
# 920           พัทลุง  2564  ธันวาคม           223
# 921          ปัตตานี  2564  ธันวาคม           342
# 922             ยะลา  2564  ธันวาคม           530
# 923         นราธิวาส  2564  ธันวาคม           115
#
# [924 rows x 4 columns]

# %%
data_Labour.isnull().any()
# Out:
# province         False
# year             False
# month            False
# Labour Demand    False
# dtype: bool

# %% [markdown]
# ###รวมตาราง confirmed-cases 1 กับ ภูมิภาค และ ข้อมูลความต้องการแรงงาน เข้าด้วยกัน

# %%
case_pro11 = case_pro1.merge(data_Labour,how='right',left_on='province_of_onset',right_on = 'province')
case_pro11
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0             1     12/1/2020   ไม่มีข้อมูล  หญิง  61.0   ปี       China
# 1             2     17/1/2020   ไม่มีข้อมูล  หญิง  74.0   ปี       China
# 2             4     22/1/2020   ไม่มีข้อมูล   ชาย  68.0   ปี       China
# 3             5     24/1/2020   ไม่มีข้อมูล  หญิง  66.0   ปี       China
# 4             6     25/1/2020   ไม่มีข้อมูล  หญิง  33.0   ปี       China
# ...         ...           ...           ...   ...   ...  ...         ...
# 8631379  807644     11/8/2021     10/8/2021  หญิง  34.0   ปี    Thailand
# 8631380  807645     11/8/2021     10/8/2021   ชาย  56.0   ปี    Thailand
# 8631381  807646     11/8/2021     10/8/2021  หญิง  32.0   ปี    Thailand
# 8631382  807647     11/8/2021     10/8/2021  หญิง  49.0   ปี    Thailand
# 8631383  807648     11/8/2021     10/8/2021  หญิง  35.0   ปี    Thailand
#
#         province_of_isolation                                         risk  \
# 0               กรุงเทพมหานคร             คนต่างชาติเดินทางมาจากต่างประเทศ
# 1               กรุงเทพมหานคร             คนต่างชาติเดินทางมาจากต่างประเทศ
# 2               กรุงเทพมหานคร             คนต่างชาติเดินทางมาจากต่างประเทศ
# 3                     นนทบุรี             คนต่างชาติเดินทางมาจากต่างประเทศ
# 4               กรุงเทพมหานคร             คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                       ...                                          ...
# 8631379              นราธิวาส                                        อื่นๆ
# 8631380              นราธิวาส  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 8631381              นราธิวาส  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 8631382              นราธิวาส  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 8631383              นราธิวาส  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
#         province_of_onset district_of_onset        จังหวัด  \
# 0           กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# 1           กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# 2           กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# 3           กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# 4           กรุงเทพมหานคร       ไม่มีข้อมูล  กรุงเทพมหานคร
# ...                   ...               ...            ...
# 8631379          นราธิวาส        สุไหงโก-ลก       นราธิวาส
# 8631380          นราธิวาส        เจาะไอร้อง       นราธิวาส
# 8631381          นราธิวาส        เจาะไอร้อง       นราธิวาส
# 8631382          นราธิวาส        เจาะไอร้อง       นราธิวาส
# 8631383          นราธิวาส        เจาะไอร้อง       นราธิวาส
#
#         6 ภูมิภาค (ภูมิศาสตร์)       province  year    month Labour Demand
# 0                         กลาง  กรุงเทพมหานคร  2564   มกราคม         4,763
# 1                         กลาง  กรุงเทพมหานคร  2564   มกราคม         4,763
# 2                         กลาง  กรุงเทพมหานคร  2564   มกราคม         4,763
# 3                         กลาง  กรุงเทพมหานคร  2564   มกราคม         4,763
# 4                         กลาง  กรุงเทพมหานคร  2564   มกราคม         4,763
# ...                        ...            ...   ...      ...           ...
# 8631379                    ใต้       นราธิวาส  2564  ธันวาคม           115
# 8631380                    ใต้       นราธิวาส  2564  ธันวาคม           115
# 8631381                    ใต้       นราธิวาส  2564  ธันวาคม           115
# 8631382                    ใต้       นราธิวาส  2564  ธันวาคม           115
# 8631383                    ใต้       นราธิวาส  2564  ธันวาคม           115
#
# [8631384 rows x 17 columns]

# %% [markdown]
# ###รวมตาราง confirmed-cases 2 กับ ภูมิภาค และ ข้อมูลความต้องการแรงงาน เข้าด้วยกัน

# %%
case_pro22 = case_pro2.merge(data_Labour,how='right',left_on='province_of_onset',right_on = 'province')
case_pro22
# Out:
#               No. announce_date Notified date   sex       age         Unit  \
# 0          817828     12/8/2021     11/8/2021  หญิง  39.00000           ปี
# 1          817831     12/8/2021     11/8/2021  หญิง  46.00000           ปี
# 2          817832     12/8/2021     11/8/2021   ชาย  22.00000           ปี
# 3          817834     12/8/2021     11/8/2021   ชาย  41.00000           ปี
# 4          817836     12/8/2021     11/8/2021   ชาย  51.00000           ปี
# ...           ...           ...           ...   ...       ...          ...
# 10738471  1857553    25/10/2021    24/10/2021   ชาย  17.00000           ปี
# 10738472  1857562    25/10/2021    24/10/2021  หญิง  74.00000           ปี
# 10738473  1857731    25/10/2021    24/10/2021  หญิง  35.67704  ไม่มีข้อมูล
# 10738474  1857878    25/10/2021    24/10/2021  หญิง  35.67704  ไม่มีข้อมูล
# 10738475  1857889    25/10/2021    24/10/2021  หญิง  35.67704  ไม่มีข้อมูล
#
#          nationality province_of_isolation                  risk  \
# 0           Thailand             กำแพงเพชร                 อื่นๆ
# 1           Thailand             กำแพงเพชร                 อื่นๆ
# 2           Thailand             กำแพงเพชร                 อื่นๆ
# 3           Thailand             กำแพงเพชร                 อื่นๆ
# 4           Thailand             กำแพงเพชร                 อื่นๆ
# ...              ...                   ...                   ...
# 10738471    Thailand               ปัตตานี                 อื่นๆ
# 10738472    Thailand               ปัตตานี                 อื่นๆ
# 10738473    Thailand                  ยะลา  อยู่ระหว่างการสอบสวน
# 10738474    Thailand                  ยะลา  อยู่ระหว่างการสอบสวน
# 10738475    Thailand                  ยะลา  อยู่ระหว่างการสอบสวน
#
#          province_of_onset district_of_onset        จังหวัด  \
# 0            กรุงเทพมหานคร         ป้อมปราบฯ  กรุงเทพมหานคร
# 1            กรุงเทพมหานคร          เพชรเกษม  กรุงเทพมหานคร
# 2            กรุงเทพมหานคร          ห้วยขวาง  กรุงเทพมหานคร
# 3            กรุงเทพมหานคร             บางนา  กรุงเทพมหานคร
# 4            กรุงเทพมหานคร             บางแค  กรุงเทพมหานคร
# ...                    ...               ...            ...
# 10738471          นราธิวาส            บาเจาะ       นราธิวาส
# 10738472          นราธิวาส            บาเจาะ       นราธิวาส
# 10738473          นราธิวาส         เมืองยะลา       นราธิวาส
# 10738474          นราธิวาส        สุไหงโก-ลก       นราธิวาส
# 10738475          นราธิวาส     เมืองนราธิวาส       นราธิวาส
#
#          6 ภูมิภาค (ภูมิศาสตร์)       province  year    month Labour Demand
# 0                          กลาง  กรุงเทพมหานคร  2564   มกราคม         4,763
# 1                          กลาง  กรุงเทพมหานคร  2564   มกราคม         4,763
# 2                          กลาง  กรุงเทพมหานคร  2564   มกราคม         4,763
# 3                          กลาง  กรุงเทพมหานคร  2564   มกราคม         4,763
# 4                          กลาง  กรุงเทพมหานคร  2564   มกราคม         4,763
# ...                         ...            ...   ...      ...           ...
# 10738471                    ใต้       นราธิวาส  2564  ธันวาคม           115
# 10738472                    ใต้       นราธิวาส  2564  ธันวาคม           115
# 10738473                    ใต้       นราธิวาส  2564  ธันวาคม           115
# 10738474                    ใต้       นราธิวาส  2564  ธันวาคม           115
# 10738475                    ใต้       นราธิวาส  2564  ธันวาคม           115
#
# [10738476 rows x 17 columns]

# %% [markdown]
# ###รวมตาราง confirmed-cases 3 กับ ภูมิภาค และ ข้อมูลความต้องการแรงงาน เข้าด้วยกัน

# %%
case_pro33 = case_pro3.merge(data_Labour,how='right',left_on='province_of_onset',right_on = 'province')
case_pro33
# Out:
#               No. announce_date Notified date          sex   age Unit  \
# 0         1860176    26/10/2021    25/10/2021         หญิง  34.0   ปี
# 1         1860177    26/10/2021    25/10/2021         หญิง  34.0   ปี
# 2         1860178    26/10/2021    25/10/2021         หญิง  24.0   ปี
# 3         1860179    26/10/2021    25/10/2021         หญิง  55.0   ปี
# 4         1860180    26/10/2021    25/10/2021          ชาย  33.0   ปี
# ...           ...           ...           ...          ...   ...  ...
# 10774723  2865995     27/2/2022     26/2/2022          ชาย  36.0   ปี
# 10774724  2865996     27/2/2022     26/2/2022         หญิง  23.0   ปี
# 10774725  2866410     27/2/2022     26/2/2022          ชาย  35.0   ปี
# 10774726  2866413     27/2/2022     26/2/2022         หญิง  32.0   ปี
# 10774727  2867840     27/2/2022     26/2/2022  ไม่มีข้อมูล  44.0   ปี
#
#           nationality province_of_isolation  \
# 0            Thailand              ปทุมธานี
# 1            Thailand              ปทุมธานี
# 2            Thailand              ปทุมธานี
# 3            Thailand              ปทุมธานี
# 4            Thailand              ปทุมธานี
# ...               ...                   ...
# 10774723     Thailand              นราธิวาส
# 10774724     Thailand              นราธิวาส
# 10774725     Thailand               ปัตตานี
# 10774726     Thailand               ปัตตานี
# 10774727  ไม่มีข้อมูล         กรุงเทพมหานคร
#
#                                                       risk province_of_onset  \
# 0                                     อยู่ระหว่างการสอบสวน     กรุงเทพมหานคร
# 1                                     อยู่ระหว่างการสอบสวน     กรุงเทพมหานคร
# 2                                     อยู่ระหว่างการสอบสวน     กรุงเทพมหานคร
# 3                                     อยู่ระหว่างการสอบสวน     กรุงเทพมหานคร
# 4                                     อยู่ระหว่างการสอบสวน     กรุงเทพมหานคร
# ...                                                    ...               ...
# 10774723       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้          นราธิวาส
# 10774724                                         สถานศึกษา          นราธิวาส
# 10774725                                             อื่นๆ          นราธิวาส
# 10774726  การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน          นราธิวาส
# 10774727     ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว          นราธิวาส
#
#          district_of_onset  Unnamed: 11        จังหวัด 6 ภูมิภาค (ภูมิศาสตร์)  \
# 0                   บางเขน  ไม่มีข้อมูล  กรุงเทพมหานคร                   กลาง
# 1                   บางเขน  ไม่มีข้อมูล  กรุงเทพมหานคร                   กลาง
# 2                 ลาดพร้าว  ไม่มีข้อมูล  กรุงเทพมหานคร                   กลาง
# 3                   สายไหม  ไม่มีข้อมูล  กรุงเทพมหานคร                   กลาง
# 4                   บางเขน  ไม่มีข้อมูล  กรุงเทพมหานคร                   กลาง
# ...                    ...          ...            ...                    ...
# 10774723        เจาะไอร้อง  ไม่มีข้อมูล       นราธิวาส                    ใต้
# 10774724        เจาะไอร้อง  ไม่มีข้อมูล       นราธิวาส                    ใต้
# 10774725     เมืองนราธิวาส  ไม่มีข้อมูล       นราธิวาส                    ใต้
# 10774726           ศรีสาคร  ไม่มีข้อมูล       นราธิวาส                    ใต้
# 10774727              แว้ง  ไม่มีข้อมูล       นราธิวาส                    ใต้
#
#                province  year    month Labour Demand
# 0         กรุงเทพมหานคร  2564   มกราคม         4,763
# 1         กรุงเทพมหานคร  2564   มกราคม         4,763
# 2         กรุงเทพมหานคร  2564   มกราคม         4,763
# 3         กรุงเทพมหานคร  2564   มกราคม         4,763
# 4         กรุงเทพมหานคร  2564   มกราคม         4,763
# ...                 ...   ...      ...           ...
# 10774723       นราธิวาส  2564  ธันวาคม           115
# 10774724       นราธิวาส  2564  ธันวาคม           115
# 10774725       นราธิวาส  2564  ธันวาคม           115
# 10774726       นราธิวาส  2564  ธันวาคม           115
# 10774727       นราธิวาส  2564  ธันวาคม           115
#
# [10774728 rows x 18 columns]

# %% [markdown]
# ###รวมตาราง confirmed-cases 4 กับ ภูมิภาค และ ข้อมูลความต้องการแรงงาน เข้าด้วยกัน

# %%
case_pro44 = case_pro4.merge(data_Labour,how='right',left_on='province_of_onset',right_on = 'province')
case_pro44
# Out:
#              No. announce_date Notified date          sex   age Unit  \
# 0        2870089     28/2/2022     27/2/2022          ชาย  21.0   ปี
# 1        2870600     28/2/2022     27/2/2022          ชาย   1.0   ปี
# 2        2870601     28/2/2022     27/2/2022          ชาย   3.0   ปี
# 3        2871499     28/2/2022     27/2/2022         หญิง   6.0   ปี
# 4        2874747     28/2/2022     27/2/2022         หญิง  49.0   ปี
# ...          ...           ...           ...          ...   ...  ...
# 4649083  3297872     18/3/2022     17/3/2022          ชาย  16.0   ปี
# 4649084  3298018     18/3/2022     17/3/2022          ชาย  56.0   ปี
# 4649085  3298348     18/3/2022     17/3/2022          ชาย  83.0   ปี
# 4649086  3300146     18/3/2022     17/3/2022  ไม่มีข้อมูล  21.0   ปี
# 4649087  3300379     18/3/2022     17/3/2022  ไม่มีข้อมูล   1.0   ปี
#
#          nationality province_of_isolation  \
# 0           Thailand                  น่าน
# 1           Thailand              พิษณุโลก
# 2           Thailand              พิษณุโลก
# 3           Thailand               นครนายก
# 4           Thailand             สมุทรสาคร
# ...              ...                   ...
# 4649083     Thailand                 สงขลา
# 4649084     Thailand                 สงขลา
# 4649085     Thailand                  ยะลา
# 4649086  ไม่มีข้อมูล         กรุงเทพมหานคร
# 4649087  ไม่มีข้อมูล         กรุงเทพมหานคร
#
#                                                 risk province_of_onset  \
# 0                                              อื่นๆ     กรุงเทพมหานคร
# 1                                              อื่นๆ     กรุงเทพมหานคร
# 2                                              อื่นๆ     กรุงเทพมหานคร
# 3        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้     กรุงเทพมหานคร
# 4                                       สถานที่ทำงาน     กรุงเทพมหานคร
# ...                                              ...               ...
# 4649083                                        อื่นๆ          นราธิวาส
# 4649084  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้          นราธิวาส
# 4649085                         อยู่ระหว่างการสอบสวน          นราธิวาส
# 4649086                                        อื่นๆ          นราธิวาส
# 4649087                                        อื่นๆ          นราธิวาส
#
#         district_of_onset        จังหวัด 6 ภูมิภาค (ภูมิศาสตร์)  \
# 0               เมืองน่าน  กรุงเทพมหานคร                   กลาง
# 1               เขตพระนคร  กรุงเทพมหานคร                   กลาง
# 2               เขตพระนคร  กรุงเทพมหานคร                   กลาง
# 3              เขตบางกะปิ  กรุงเทพมหานคร                   กลาง
# 4             บางขุนเทียน  กรุงเทพมหานคร                   กลาง
# ...                   ...            ...                    ...
# 4649083              แว้ง       นราธิวาส                    ใต้
# 4649084             ตากใบ       นราธิวาส                    ใต้
# 4649085           รือเสาะ       นราธิวาส                    ใต้
# 4649086           รือเสาะ       นราธิวาส                    ใต้
# 4649087             ตากใบ       นราธิวาส                    ใต้
#
#               province  year    month Labour Demand
# 0        กรุงเทพมหานคร  2564   มกราคม         4,763
# 1        กรุงเทพมหานคร  2564   มกราคม         4,763
# 2        กรุงเทพมหานคร  2564   มกราคม         4,763
# 3        กรุงเทพมหานคร  2564   มกราคม         4,763
# 4        กรุงเทพมหานคร  2564   มกราคม         4,763
# ...                ...   ...      ...           ...
# 4649083       นราธิวาส  2564  ธันวาคม           115
# 4649084       นราธิวาส  2564  ธันวาคม           115
# 4649085       นราธิวาส  2564  ธันวาคม           115
# 4649086       นราธิวาส  2564  ธันวาคม           115
# 4649087       นราธิวาส  2564  ธันวาคม           115
#
# [4649088 rows x 17 columns]

# %%
case_pro11.to_csv('case_pro11.csv')

# %%
case_pro22.to_csv('case_pro22.csv')

# %%
case_pro33.to_csv('case_pro33.csv')

# %%
case_pro44.to_csv('case_pro44.csv')
