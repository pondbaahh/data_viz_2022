# %% [markdown]
# <a href="https://colab.research.google.com/github/pondbaahh/data_viz_2022/blob/main/Final_Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive #เชื่อมเข้ากับ Drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os #os เอาไว้จัดการไฟล์และ path

# %%
path = '/content/drive/My Drive/DataViz22_data'

# %%
alldb = pd.read_csv(os.path.join(path, 'alldb.csv'))

# %%
hospital = os.path.join(path,'hospital_list.xlsx')
hospital = pd.read_excel(hospital)

# %% [markdown]
# ###ข้อมูล alldb

# %%
alldb
# Out:
#        Unnamed: 0           user                                    RowKey  \
# 0               0           test                                       NaN
# 1               1          04857      136FD222-FD9F-4E54-AE1F-7282A276B085
# 2               2            NaN  1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png
# 3               3  3450101576642      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE
# 4               4  3450101576642      45197AF7-7CB4-470C-9ABB-37C092BD6B21
# ...           ...            ...                                       ...
# 40030       40030            NaN      6B5FA20F-190E-4021-8547-C12308024C6C
# 40031       40031            NaN      F48C51C0-A345-40D6-93F4-46213267E1B1
# 40032       40032            NaN      A986BDAA-6D7C-4017-8E62-A3C104E946B9
# 40033       40033            NaN                            bbuogxulur.png
# 40034       40034            NaN                            zttpqogiso.png
#
#       care        date   ov             phone   site      time  \
# 0      NaN         NaN  NaN               NaN    NaN       NaN
# 1      NaN  2022-02-24  NaN        iPhone10,4  05310  10:50:32
# 2      NaN         NaN  NaN               NaN    NaN       NaN
# 3      NaN  2022-02-23    0        iPhone13,4  05087  09:59:47
# 4      NaN  2022-02-23  NaN        iPhone13,4  05087  09:44:06
# ...    ...         ...  ...               ...    ...       ...
# 40030  NaN         NaN  NaN        iPhone13,4  01234       NaN
# 40031  NaN         NaN    2        iPhone10,5  01234       NaN
# 40032  NaN         NaN    1        iPhone13,4  01234       NaN
# 40033  NaN         NaN  NaN  Samsung SM-A115F  01234       NaN
# 40034  NaN         NaN    1  Samsung SM-A115F  01234       NaN
#
#                  urine  pid            PartitionKey                  title  \
# 0                  NaN  NaN                     NaN  data is not completed
# 1                  NaN  NaN                     NaN  data is not completed
# 2                  NaN  NaN                     NaN  data is not completed
# 3      ปกติ (เหลืองใส)  NaN                     NaN  data is not completed
# 4      ปกติ (เหลืองใส)  NaN                     NaN  data is not completed
# ...                ...  ...                     ...                    ...
# 40030              NaN    5     เกษศิรินทร์  ไชยลาภ  data is not completed
# 40031  ปกติ (เหลืองใส)    5  เถลิงเกียรติ เสริฐเลิศ  data is not completed
# 40032  ปกติ (เหลืองใส)    1                    เสรี  data is not completed
# 40033              NaN    1                    เสรี  data is not completed
# 40034  ปกติ (เหลืองใส)    1                    เสรี  data is not completed
#
#                          age
# 0      data is not completed
# 1      data is not completed
# 2      data is not completed
# 3      data is not completed
# 4      data is not completed
# ...                      ...
# 40030  data is not completed
# 40031  data is not completed
# 40032  data is not completed
# 40033  data is not completed
# 40034  data is not completed
#
# [40035 rows x 14 columns]

# %% [markdown]
# ###ข้อมูล hospital

# %%
hospital
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
#                       zone_name  provincecode         province  amphurcode  \
# 0            สาขาพื้นที่(ระยอง)          11.0      สมุทรปราการ         1.0
# 1          สาขาพื้นที่(สระบุรี)          12.0          นนทบุรี         1.0
# 2          สาขาพื้นที่(สระบุรี)          13.0         ปทุมธานี         1.0
# 3          สาขาพื้นที่(สระบุรี)          14.0  พระนครศรีอยุธยา         1.0
# 4          สาขาพื้นที่(สระบุรี)          15.0          อ่างทอง         1.0
# ...                         ...           ...              ...         ...
# 17098     สาขาพื้นที่(พิษณุโลก)          53.0        อุตรดิตถ์         1.0
# 17099      สาขาพื้นที่(ราชบุรี)          77.0  ประจวบคีรีขันธ์         2.0
# 17100      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         9.0
# 17101  สาขาพื้นที่(อุบลราชธานี)          33.0         ศรีสะเกษ         1.0
# 17102      สาขาพื้นที่(ราชบุรี)          70.0          ราชบุรี         6.0
#
#                  amphur  tamboncode     tambon  code4  \
# 0      เมืองสมุทรปราการ         1.0     ปากน้ำ    1.0
# 1          เมืองนนทบุรี         4.0   บางกระสอ    1.0
# 2         เมืองปทุมธานี         1.0    บางปรอก    1.0
# 3       พระนครศรีอยุธยา         3.0  หอรัตนไชย    1.0
# 4          เมืองอ่างทอง         8.0    บ้านอิฐ    1.0
# ...                 ...         ...        ...    ...
# 17098    เมืองอุตรดิตถ์         1.0     ท่าอิฐ    8.0
# 17099           กุยบุรี         1.0    กุยบุรี    8.0
# 17100           วัดเพลง         3.0    วัดเพลง    8.0
# 17101     เมืองศรีสะเกษ        11.0     โพนข่า    8.0
# 17102             บางแพ         2.0    วังเย็น    8.0
#
#                           name5  code9     name10 short_thai short_english
# 0      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         สป           SPK
# 1      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         นบ           NBI
# 2      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         ปท           PTE
# 3      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         อย           AYA
# 4      สำนักงานสาธารณสุขจังหวัด    NaN        NaN         อท           ATG
# ...                         ...    ...        ...        ...           ...
# 17098  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         อต           UTT
# 17099  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ปข           PKN
# 17100  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
# 17101  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         ศก           SSK
# 17102  ศูนย์สุขภาพชุมชน ของ รพ.   10.0  1 ปฐมภูมิ         รบ           RBR
#
# [17103 rows x 16 columns]

# %% [markdown]
# ###เลือก Column ที่ต้องการใช้งานต่อ

# %%
alldb2 = alldb[['user','RowKey','date','phone','site','time','urine','ov','PartitionKey']] 
alldb2
# Out:
#                 user                                    RowKey        date  \
# 0               test                                       NaN         NaN
# 1              04857      136FD222-FD9F-4E54-AE1F-7282A276B085  2022-02-24
# 2                NaN  1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png         NaN
# 3      3450101576642      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE  2022-02-23
# 4      3450101576642      45197AF7-7CB4-470C-9ABB-37C092BD6B21  2022-02-23
# ...              ...                                       ...         ...
# 40030            NaN      6B5FA20F-190E-4021-8547-C12308024C6C         NaN
# 40031            NaN      F48C51C0-A345-40D6-93F4-46213267E1B1         NaN
# 40032            NaN      A986BDAA-6D7C-4017-8E62-A3C104E946B9         NaN
# 40033            NaN                            bbuogxulur.png         NaN
# 40034            NaN                            zttpqogiso.png         NaN
#
#                   phone   site      time            urine   ov  \
# 0                   NaN    NaN       NaN              NaN  NaN
# 1            iPhone10,4  05310  10:50:32              NaN  NaN
# 2                   NaN    NaN       NaN              NaN  NaN
# 3            iPhone13,4  05087  09:59:47  ปกติ (เหลืองใส)    0
# 4            iPhone13,4  05087  09:44:06  ปกติ (เหลืองใส)  NaN
# ...                 ...    ...       ...              ...  ...
# 40030        iPhone13,4  01234       NaN              NaN  NaN
# 40031        iPhone10,5  01234       NaN  ปกติ (เหลืองใส)    2
# 40032        iPhone13,4  01234       NaN  ปกติ (เหลืองใส)    1
# 40033  Samsung SM-A115F  01234       NaN              NaN  NaN
# 40034  Samsung SM-A115F  01234       NaN  ปกติ (เหลืองใส)    1
#
#                  PartitionKey
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 40030     เกษศิรินทร์  ไชยลาภ
# 40031  เถลิงเกียรติ เสริฐเลิศ
# 40032                    เสรี
# 40033                    เสรี
# 40034                    เสรี
#
# [40035 rows x 9 columns]

# %% [markdown]
# ###ตรวจสอบค่า Missing ข้อมูล alldb

# %%
alldb2.isnull().any()
# Out:
# user            True
# RowKey          True
# date            True
# phone           True
# site            True
# time            True
# urine           True
# ov              True
# PartitionKey    True
# dtype: bool

# %% [markdown]
# ### ตัดค่า Missing โดยการ dropna()

# %%
alldb3 = alldb2.dropna()
alldb3
# Out:
#          user                                RowKey        date  \
# 185     85879                        shmpdrmtgc.png  2022-03-24
# 186    45-161  D2CABB8C-533B-450A-AFA6-B693749CC1C6  2022-02-23
# 187    45-161  57A5F06C-C840-49EA-9514-A30D3C897CC8  2022-02-23
# 188     27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1  2022-02-25
# 190     06223                        kfpwuaqldj.png  2022-03-23
# ...       ...                                   ...         ...
# 40013   ttest                        crqcufokmn.png  2022-02-21
# 40014   ttest                        gzxgflnowr.png  2022-02-21
# 40016     xxx                        jytlopevha.png  2022-02-17
# 40022     yyy                        ivccsksowb.png  2022-02-17
# 40023     zzz                        psudrnccsh.png  2022-02-17
#
#                    phone   site      time            urine ov PartitionKey
# 185         OPPO CPH2293  05194  13:08:39          มีตะกอน  0         0000
# 186           iPhone11,8  04312  09:45:28  ปกติ (เหลืองใส)  0       0-1528
# 187           iPhone11,8  04312  10:06:45  ปกติ (เหลืองใส)  0       0-1544
# 188           iPhone13,1  04999  14:22:22  ปกติ (เหลืองใส)  0         0000
# 190    Xiaomi 21081111RG  13777  16:31:45  ปกติ (เหลืองใส)  0        00000
# ...                  ...    ...       ...              ... ..          ...
# 40013   Samsung SM-G998B   test  14:23:45             ขุ่น  2         x001
# 40014   Samsung SM-G998B   test  14:23:43             ขุ่น  2         x001
# 40016   Samsung SM-N950F    xxx  00:01:06  ปกติ (เหลืองใส)  3          xxx
# 40022   Samsung SM-N950F    yyy  08:41:05   มีเม็ดเลือดแดง  2          yyy
# 40023   Samsung SM-N950F    zzz  08:41:04          มีตะกอน  2          zzz
#
# [38663 rows x 9 columns]

# %%
set(alldb3['date'])
# Out:
# {'2022-02-15',
#  '2022-02-16',
#  '2022-02-17',
#  '2022-02-18',
#  '2022-02-19',
#  '2022-02-20',
#  '2022-02-21',
#  '2022-02-22',
#  '2022-02-23',
#  '2022-02-24',
#  '2022-02-25',
#  '2022-02-26',
#  '2022-02-27',
#  '2022-02-28',
#  '2022-03-01',
#  '2022-03-02',
#  '2022-03-03',
#  '2022-03-04',
#  '2022-03-05',
#  '2022-03-06',
#  '2022-03-07',
#  '2022-03-08',
#  '2022-03-09',
#  '2022-03-10',
#  '2022-03-11',
#  '2022-03-12',
#  '2022-03-13',
#  '2022-03-14',
#  '2022-03-15',
#  '2022-03-16',
#  '2022-03-17',
#  '2022-03-18',
#  '2022-03-19',
#  '2022-03-20',
#  '2022-03-21',
#  '2022-03-22',
#  '2022-03-23',
#  '2022-03-24',
#  '2022-03-25',
#  '2022-03-26',
#  '2022-03-27',
#  '2022-03-28',
#  '2022-03-29',
#  '2022-03-30',
#  '2022-03-31',
#  '2022-04-01',
#  '2022-04-02',
#  '2022-04-03',
#  '2022-04-04',
#  '2022-04-05'}

# %%
set(alldb3['RowKey'])
# Out:
# {'032A0F18-7A2B-46CF-A95C-59F21171987E',
#  'E0FDF999-7677-4735-8F2A-62FA02EF5E9D',
#  'ncbxyvjaqu.png',
#  'B19E60C5-0F29-48A3-8D56-F4BC84466980',
#  'ftfoqqinks.png',
#  'EE0351D7-54FF-42DE-B7C3-4A84A06B44DF',
#  'CCD72601-C5A6-4EE8-A1F0-3C95ECD24987',
#  'A4D569F9-8C32-4C28-8F55-9EE511D32CF1',
#  'DF6CE540-1FF4-454C-8AA6-0B66A51007C9',
#  '22B5AE7D-A978-495F-8890-357BD83E1A68',
#  'CFE69E99-72A1-4F0F-8CD2-742667FE5BD4',
#  '0B8F2499-AE41-47C6-A5A8-9889D87588C7',
#  '302C338C-759D-4B1F-AEB2-D8A76D2FEDAA',
#  'tbcugtqtvn.png',
#  '43BF0C90-5FDC-48BF-8ED8-DC273692F5CE',
#  '1378055F-DBE6-4AE8-ACA1-7C24CAF6D751',
#  '5E821BE7-E8EE-4CDC-A5DD-BC5DE51CBC02',
#  'rnmvxuorar.png',
#  'A6EE38D4-12B4-42EF-BA4F-2F369CE9B6E9',
#  '755DA847-2B39-47DE-9E62-D35CFBE3CDC7',
#  '18CA0ADC-B2D3-43C0-B0CC-4AA6A8DB6639',
#  '8E1CA69B-B211-4A4F-B792-8CE98C811EBB',
#  'DA8FB84B-066F-47F6-BFA7-0EEA8E2A08C8',
#  'A1805814-281E-4C27-8638-8B072B4C3709',
#  'kizgvvkvbs.png',
#  'A43E46CA-536A-469A-9F87-B730A20B6032',
#  'uqlkfgnpzd.png',
#  'hawauffdbf.png',
#  'cjhjmqgchn.png',
#  'hrfkpytqgt.png',
#  '88C6B474-4B3A-446E-847A-71FF26D8A360',
#  '9BF0EF0B-1F31-4E02-B35D-560CD7E101D9',
#  'B96A497A-19DF-4ACF-9F9E-98158B97EDB2',
#  '1E17CB8B-58A5-478A-8DD7-BF5041E452B6',
#  'touzgrxfjy.png',
#  '3381BA60-CD80-494F-9D34-2E5D6E0F11DD',
#  '9A12EFD7-B900-4998-BFFE-E8CFF93F52C9',
#  'fhpboplpwo.png',
#  'rtvitjogbb.png',
#  'arjulvlijc.png',
#  'qcznqmvtqs.png',
#  '93790D00-AC88-45F2-A7C3-5A4C1A9CE956',
#  'E0470B35-654A-4F7F-863F-2B98E707C1EC',
#  'jeimvmttlg.png',
#  'DBEC63DF-9B30-4CA8-8AD1-B862855BB248',
#  '7983A13B-6BFA-4FE6-886D-4EFDC43AED0B',
#  'umqqiwmjbj.png',
#  'ymelzaibls.png',
#  '7C89A015-B5B9-404A-A35B-0865A0DFC371',
#  'B6221873-B8F5-40CA-A71A-0B5DAA785D22',
#  'kwgfkubwva.png',
#  'dpxoifjtwp.png',
#  'AE3C4283-26F8-45B8-9B20-3E9D448D32B4',
#  '19B87170-2D8B-44F1-95B4-59475515BE09',
#  'archvoiyfb.png',
#  'EB0DE079-4B10-4AC6-8CD5-B15C4585BEC7',
#  'lrtvfxaycb.png',
#  '71542EF1-CD70-4AFB-A6E2-DAF5FC49EC27',
#  'D817A419-06BF-4D5E-BD35-6E5792C6B49F',
#  'xwgvwrxced.png',
#  'aulkoysuzh.png',
#  '993097A6-C16A-4F70-8680-0B4C6B6AEA12',
#  'ifdirmvzai.png',
#  '7A0AC52A-06EC-43C6-A85C-27DF0D5434C1',
#  'E0B33214-F375-4541-A7E9-CBDB1AC0DF19',
#  'undnladqia.png',
#  'alwvfdhicx.png',
#  'xjaolmxpgd.png',
#  'BF5A5F60-7BE5-494D-B245-1457F84B188F',
#  'AB2AF586-D9FD-4E19-B2D9-C7EB2D92E860',
#  '84F3D402-5C15-4E1D-AEC7-6755C3876871',
#  'kcopncwvdj.png',
#  'F5E24DC0-9ED5-408D-92BB-8ADCFFD4D4CD',
#  '3AAC8C25-ABA6-4FEE-AB0F-B8E5F81A552F',
#  'uvwgiucllh.png',
#  'gpkkiqpmuu.png',
#  'BD50718D-30E6-463D-ABD2-16F6C4B3FF33',
#  'qasejilooc.png',
#  '5D4967D4-44C6-4185-B3FE-2F83A08711CD',
#  'skobyifpyc.png',
#  'agghksbwcc.png',
#  'exnqwhjhoj.png',
#  '84C5DF33-8C64-46A2-8268-14D2F3B41CFD',
#  '4BDEF9A4-42E8-4670-8114-399192F5B1C7',
#  'B9B0A60C-2DAF-4564-9955-A5C6495F96A4',
#  'pqooyziyro.png',
#  '8BA247E2-EE55-4184-A804-5B69F2636DD1',
#  'C7E0CB3D-0E81-46E7-B014-8F9D4DA7F73E',
#  'F620F5F9-E7F3-4A5C-9573-7597E3AE370D',
#  'vexdpdzsxc.png',
#  'E0CF361A-C777-4E38-A791-1C4261C0AE77',
#  '93019E01-DF3C-4496-8F99-27E08BAA2A38',
#  'kaveuvkrae.png',
#  '40F7F9EE-E59C-4887-89E1-BD0FD2C1506E',
#  'zvtankjfqr.png',
#  'D14E59C9-82D9-4C8E-B08B-89BE2F7F448D',
#  'bxgwcwkymf.png',
#  '9FA9E8A9-6CAD-442D-9C05-02915BBEEE8F',
#  '02BA3A13-F70F-45BB-A66B-3ED951B993B8',
#  'xwfmsnpigw.png',
#  '03CBDD12-000C-487D-A43D-01D9600806C6',
#  '026FD857-F533-4AF4-A269-19E1C81ECA92',
#  '5F0D7BAC-0352-4A21-928D-B6B8471B7623',
#  'nuxkwylkok.png',
#  'DA97E1E5-ED05-4753-B848-4E039B54E213',
#  'mzlxazgtxh.png',
#  '6D4B7E79-FE5A-45D6-B73B-0B874544014D',
#  '34D176B1-7E3B-4C71-AC79-BE7246D13539',
#  'fhmzbhqwfg.png',
#  'gefgglnnnd.png',
#  'E6FAFDAC-6296-411D-B23D-B1B4757F4011',
#  'pelhqsxqes.png',
#  'dknsyisdxu.png',
#  '7986EDDB-ED91-439F-82FB-135924A9DA66',
#  '0C23AD2C-5702-40E9-8011-B8EAAC033411',
#  '636B3FA1-6E94-4E7B-B611-865954F1703E',
#  'A8DAF9EB-8FD9-4540-9CE2-39155469F1B7',
#  'C9A55D77-4F6E-4EFA-9F61-BCE058EA17E7',
#  '2B01B1C4-4432-40C9-AD64-8694D1CC6CEE',
#  'C94B4D70-7193-4573-AB63-4869046BDC29',
#  '5A806520-F195-4F6E-9A31-2AF86AC07669',
#  'jhkfappdum.png',
#  'dvtvfkdsdu.png',
#  'F1413C79-6EBC-45A8-90DF-2556D2A53C5B',
#  'qqkcvbvtjm.png',
#  'A02AFD87-EFB7-40D7-819F-638A337B1686',
#  '07B713A1-5A49-4B03-AB86-BE0BEBB51878',
#  'D23E0ADD-6C55-4DF8-8941-95F226DE3C28',
#  'D7535BF0-727B-4FA8-B337-1E30348796B3',
#  'cyfiryuqqv.png',
#  'wkprrcesgr.png',
#  'C9E3C396-FB95-49AC-9642-4D595FEEA8B8',
#  'epsfvblyqv.png',
#  '17D15B7A-328A-425B-9DCC-63566C80E7AD',
#  '4451D8FC-9DC9-4832-9763-ED01E7144106',
#  '47F26A00-2FC1-42F0-880F-A46AA2CF0A2A',
#  'atqlkmavpa.png',
#  'vujxmsrnay.png',
#  'foveiemyrs.png',
#  'gopijmongj.png',
#  '036EEEDF-3D4F-4486-9252-02B054EDC1A8',
#  'uhdipiwmtr.png',
#  '7F9BA7C4-6BEF-4ADC-B706-834038F3083A',
#  'npwghpesif.png',
#  'gpyiakhalk.png',
#  'B026D08C-07F7-4E71-A1A3-AA4D2E155D1B',
#  '084FB7FB-70A4-4B62-80FA-E976E6554DCB',
#  '987C83B8-0785-4F45-AB7D-F5F3E313E7FA',
#  '9B19DF28-E38C-457C-97C5-FB18F57D74C7',
#  'C8B8A70A-9C4A-4876-982E-A83740504492',
#  'ebcfbdnuqa.png',
#  'eopomduqzf.png',
#  '9708455B-D8B4-4504-A73A-3B7049E851A3',
#  '52CF81A8-6882-42A9-BD7F-12260D641257',
#  'ujamlrtixu.png',
#  'A4F89225-8E60-46BF-AD9D-EAABB05BFC4D',
#  'bclsgyugao.png',
#  'vfjxxhwfgu.png',
#  'jxvcanjefw.png',
#  '137A8D5E-FE1E-414F-8C8B-B96F0691C7BF',
#  'A62CE695-B918-4AA9-9D61-E3AEF7504796',
#  'mnolzzuuhb.png',
#  'coxfeivpcn.png',
#  '25D29452-CAC0-4639-A277-087C4F791DEF',
#  'apwftmntvb.png',
#  '990BDDFC-CF85-4B3D-96F9-3975DCF20AF1',
#  'ygyqeaffho.png',
#  '5F1D784C-0DD9-4AF3-96E4-BF903622ABD4',
#  'nspdnlevml.png',
#  'iypduopozl.png',
#  '7EBB0E62-65FD-4A3D-81B1-313340020602',
#  'splvgharjt.png',
#  'rlcswxjlli.png',
#  'D5C8D233-A586-470C-920A-E9B15E7E5B40',
#  '5E82C3AE-7ECF-49E7-8E38-1CA0EE4970FE',
#  'icytvqykyx.png',
#  'E323D37E-559A-4090-8971-0167BE6FD507',
#  'E7C6BD43-70C0-489A-9EDE-237A6F6C4061',
#  'yyumhmopli.png',
#  'muuoaxkayb.png',
#  'avlxnbjrxq.png',
#  '93D3CB73-703D-4973-83A7-8343EB9FB5E6',
#  'D82DAC9E-9899-4E94-BFF1-1A8C174466D6',
#  'DA6FCA92-E36D-460B-8231-23958D8F75DE',
#  '261FAA24-23B7-40C9-B36B-A571250DC89A',
#  'kcqsinzntd.png',
#  'moswwdywzx.png',
#  '01832849-3466-47C8-B99F-6156298E96DE',
#  'mrigwdftby.png',
#  'yoencldwdz.png',
#  'ioyfjwjooe.png',
#  'omijamdwpe.png',
#  'gfxzrsxafo.png',
#  '33B6F2FD-3882-4E9E-B28C-24266E0FBD8D',
#  '0B1FABD6-7248-4C35-9155-F54F12C0CCF0',
#  'DF67AACA-55A2-481C-8766-9242DAA9FFC0',
#  'C61705B6-AE11-4FDA-819B-9C608E0F54CD',
#  'B6AA84D5-68A2-4BFA-8795-19C9310F4827',
#  'sscfmbpsqn.png',
#  'bhzdqbdefy.png',
#  'D300617A-D700-4720-B124-89C33033D88F',
#  'vmuvyqqnou.png',
#  'nilvhcnzeo.png',
#  'stuymqklet.png',
#  'F3234D1C-7CF1-48F5-B255-0F5A72010F49',
#  'jdpbhlyowm.png',
#  'CB563189-1B9F-4676-9531-1F377CB21552',
#  '29C8A961-C005-4311-A7D1-A17CAC4C5448',
#  '27115096-442B-406A-852A-6DA76C3886DB',
#  'DE85C5F9-AFCD-451D-B63B-FEECE8A62DCE',
#  'A5E630D2-60C3-4359-9494-5E78C34D8065',
#  '91744D5E-C159-462C-A79D-7DFEA6111648',
#  'ybqfsfphku.png',
#  '47A4BCD9-2220-4594-8580-B221055AC036',
#  '53DACD1A-A2EB-42CD-A7D6-A3B965868785',
#  '79CBAC98-AC5B-42EE-A0C8-4A798682F019',
#  'E4C90400-CBF9-409D-8DE4-44574F780E4E',
#  'bcbgoxlwya.png',
#  'glskukirmy.png',
#  'A623B79C-A906-4084-8DBB-61E450B9BB1E',
#  'wcjzhrlust.png',
#  'BACB1519-1B2B-441C-9E9B-67A07CE6C860',
#  '62A34C2B-9882-4EAA-9EB6-C5410B8ADD23',
#  'tluokccfjz.png',
#  '9CA3881A-5275-442C-9F1D-A20A9A9A0C11',
#  'B60A740F-8108-490D-9136-15B750E13412',
#  'C648C4EE-3882-47BA-B7BD-0BDF15D9F0C1',
#  '1F290BAC-50F6-4FCE-A718-24F3CAA5CD06',
#  'F00C2167-809D-468B-AC8A-8FE025BB5A1D',
#  '5ECD5232-6D20-4B35-A6EA-037F93328A90',
#  '4B36C883-F9A5-404B-8625-6FD9DE1F8042',
#  '5C2187D0-539B-4DD4-AA5B-047BF026B069',
#  'jgyrddwgay.png',
#  'vuyqwumneo.png',
#  'E06F68C4-F4BE-4C97-8B91-6E8F173D2985',
#  'hjoqxnstvw.png',
#  'EA0CF744-CD1D-4A98-9BF0-6CFF18C053EC',
#  'fcmdqypqmt.png',
#  'C4F0B8A8-0A51-4689-B3F6-953C04D0B2E6',
#  'gwhwztmrjt.png',
#  '675C002A-CBF8-4C0F-B52C-417CAD0608DB',
#  'E7BD9E0D-C20D-48F7-B0AE-C55EC20B1501',
#  '71FD74A2-D907-4DC5-9AA6-79BDC9347EC4',
#  'wxgwltllkf.png',
#  'fryfbnvgkc.png',
#  '3A926CCD-DE9A-4CC9-92B1-720A77F9263A',
#  '4C34F135-2DDB-4A56-BD67-24960CDA40DE',
#  '58614D1F-AF63-43E3-AEA2-F47DA1E1E3F8',
#  'DF2A2EFD-F574-4427-AD9A-F11DAA418FB7',
#  '5B98197E-6366-4DE3-A313-48C970C59EFB',
#  'kjozuxrgob.png',
#  'gtjnfpwabw.png',
#  'mlgmlxjgge.png',
#  '75FAB374-0B51-45D6-8D15-64C3DC3D3E5D',
#  'lllrbeffak.png',
#  'oomeichkjl.png',
#  'A5F9A4C1-1903-482E-A1B3-1F6E599CA1F0',
#  'nekswojmbu.png',
#  '5CC904DF-4814-4341-9AE2-9460F0A2FB60',
#  'rafzrkrkkm.png',
#  '868BA799-7537-429C-A104-A49044794726',
#  'zanbetdzqe.png',
#  'xqmqddzgan.png',
#  'qmkrcperra.png',
#  '711DF7C6-E664-4502-9888-8CDFA85C7833',
#  '02531B2A-8455-4B5C-8FB4-2DB4EA66606C',
#  'urfkdztejg.png',
#  'sywkgzgpfo.png',
#  'iuusuvknfb.png',
#  '9578D900-FE90-4084-9DDD-AA88A436CF1D',
#  'udwdkqkaqv.png',
#  '86A18BC1-0600-4C09-834C-6023B5E5DFA8',
#  '12213F6D-5A58-4977-A282-2FBDB6725E88',
#  'FEC99596-C986-41EA-AD14-0DC9B6236C58',
#  'D129D291-2AAB-4E93-ADAD-E5EF360E5647',
#  '6950910D-F2E1-4DE2-9AE1-DC88092BF502',
#  'jrwvppokqw.png',
#  'inlpkigzxr.png',
#  'muwkulugjq.png',
#  'F6AA6271-AB4B-4F1A-ABB4-985C8E73D948',
#  '9AC50950-9B9C-4F87-AA3E-C7FF2C4DAC81',
#  'wtbpkgjlqp.png',
#  'mmqdhtdeew.png',
#  '2C0A1DF0-410E-45C0-8C7C-3CE1CEDFB86D',
#  'jfbnrreybl.png',
#  '5D2D25DE-ACC6-4493-ACBA-BD885E756CE6',
#  'vxawjckuht.png',
#  'dhyykwfxoo.png',
#  'lmbytbeakf.png',
#  'cnyauqcnyd.png',
#  '34B623C6-1DC3-40DF-8119-EB028F700B97',
#  'oghswcsscx.png',
#  '53197424-70D2-4D54-8460-3A717BF7C8F5',
#  '9D6215A4-AA7E-4A06-8167-6F52323D42BE',
#  '52AA4967-3114-41BA-BBB1-0B2260CF7DE3',
#  '5869ACA2-6CEF-4D18-B674-7B24061E44FA',
#  '59D19D8F-9CD1-42A7-84EA-A2F904997639',
#  '3AABFC59-05DD-4D93-A4B3-0DF2237CCD25',
#  '69B52488-3E04-4711-9AFA-4B7F2B2CD0A0',
#  'vprubtsjkj.png',
#  'D9D80C59-C45D-4DCC-98D4-AAE71964837D',
#  '596E9071-7062-439A-8509-69C654A50200',
#  'zydxpjsmhs.png',
#  '99D6A60F-456C-4A4C-AC3A-1B6F3141EFA8',
#  '8C5851A1-82C0-483D-805B-92BF27D8527B',
#  'B7C7D7A7-F3AC-493A-8737-55DA9CC4DFF0',
#  '82155824-F4B2-45BD-944C-BFB578851101',
#  'kvfgzefdgd.png',
#  'zrzeqjhsak.png',
#  'popdbmzttc.png',
#  'A786CE73-2E30-403B-AD51-801886E271FC',
#  'C278479F-5C14-4B76-9D6A-3956A22E6F53',
#  'cdtzamqaxr.png',
#  'mmjitejjuk.png',
#  '1D45FA26-B7CF-416D-98C2-E17F73AF2C63',
#  'orcosfdfyx.png',
#  '6828786D-8094-4273-AA56-50D0F04CF211',
#  'F9CA43CD-C790-4212-985B-6CE42BFED985',
#  'bepmcieuii.png',
#  'A8EBBCED-A722-4035-B43F-3D8849AA76DB',
#  'uxsuriambv.png',
#  'mnstfvsqci.png',
#  '68AD8D46-9C0F-44BC-A2B3-C4C37938ECE5',
#  'vequngevyt.png',
#  'ojdmixysvk.png',
#  '8F592388-8B22-4121-B755-45E6D40D5F87',
#  'E08866B0-B0EB-41BA-BB9F-6C6F5B783A43',
#  'AD6CCA25-8919-4135-8650-FEFF729BD8F9',
#  'xoeryssqet.png',
#  'B24D3074-D4E6-4A45-B359-7E076EE3A9A5',
#  '06E9D35E-0CFC-411F-AF7D-69EBB5BDEE16',
#  'teruiadphp.png',
#  'yvpvcvkhod.png',
#  '7241C001-72B0-463D-8FB1-8588A2B34E1D',
#  'B81E21F4-B8B6-48D0-BC11-6F09CB5B1C24',
#  'nsovkohuns.png',
#  'B4CA1B4F-A207-4219-ABF8-979991E32EB7',
#  'pjbgrxwacm.png',
#  '61EB380E-AAAA-491A-B43F-9EEDE21C44A7',
#  'oooncsoiab.png',
#  'whaivilhij.png',
#  'E2D093EB-7A2E-483C-912E-8D585E5BCDDC',
#  'gysfohggkv.png',
#  'rffzzfstda.png',
#  'pmxucthxuh.png',
#  '2B01C44B-08BC-4B71-BDF0-D04D2AEEE2D2',
#  '675A7741-8EB7-461E-8088-11129C35FC9F',
#  '9498BDD8-4240-4048-BD94-6DC9D7758BA7',
#  '98889B90-641E-4C50-B9DA-4196E5D0BAFA',
#  '76871AD3-7ECF-481A-A098-5FFE7AFC96F7',
#  '27432B3B-FA35-4B33-B9F7-14C4BAD510E3',
#  '974F36BD-2265-4DF3-A2F9-5306F8493312',
#  'D1E34C2F-8E5F-4E2D-B360-D5F41D118A55',
#  '91511F27-2508-46ED-A64B-BF4E2AB9EA7D',
#  '8C4FE68C-00AE-4201-AD53-CD0BEF837CAF',
#  '819DB2FF-2C22-470C-9561-605F372257B0',
#  '4D57DE28-2A6D-4BEB-B0AA-DFAF9F4EE5EA',
#  'kskpoaqdeo.png',
#  'ldhljihycm.png',
#  'bsbifruqwp.png',
#  'B7E87BC5-BAC8-4868-829B-919DEE56A92E',
#  'yvsqaroixv.png',
#  'yshaohxket.png',
#  '90F47F31-9699-4DF4-B2AE-B59E09A53D4B',
#  '47938586-3F42-41C4-9D29-934FAF2248EC',
#  'CE930D1F-9E5D-488C-A6BE-FDEFA0CCF5E7',
#  '179C4BF3-2B67-492A-B175-A818F921045A',
#  '1FFE38B7-B33D-431C-998F-4823F15B02DB',
#  'tcfzkdcvpe.png',
#  'luhjtmiebm.png',
#  'bdhtdsoict.png',
#  'dmzrjgskgf.png',
#  'F510BBBE-94BD-4D50-93C9-1B0DBB0AC0A4',
#  '904432DF-0EDD-40FE-B0BC-9D2EF8A2732A',
#  'D68D6B4D-1AC6-46E9-9999-61511D7212F0',
#  'dsshyjbcyf.png',
#  '35AF924A-4BBC-4293-9636-D26947A81DA2',
#  'EAEB2DCB-724F-4D71-9F9B-7130449C55F1',
#  'patpkpeigv.png',
#  'qcifazrnfe.png',
#  'peeqmirtfg.png',
#  'bkxvhrkrzc.png',
#  'EC2DFCA1-9554-4DC8-BE31-80147467ECC8',
#  'C18C6D1C-D87A-4948-8723-220634CD1031',
#  'cindayohwj.png',
#  'qphpgvxmfg.png',
#  '6C56DC23-D529-44FE-833D-7E905DE39A45',
#  'F1B3E578-E7C7-4440-B77D-71F7DD188B16',
#  'mndtvbozqi.png',
#  '185DE64B-05D2-464A-99C6-FF5518BA0060',
#  '7E632986-A44A-4DF6-A31A-8F58A6AA7903',
#  'iifsouucmr.png',
#  'taswmukqsk.png',
#  'wbitczclnj.png',
#  'gybjntcwsv.png',
#  'ufbamcooqc.png',
#  'xnmtzvzcar.png',
#  '240363F4-1AA2-433A-B17C-D2E2AAAD7D03',
#  '969F4244-BEB5-4058-855F-1605C16C5871',
#  'rejqzsizxb.png',
#  'wyigqpbazy.png',
#  'jaaiskqfgv.png',
#  'rkkutomafv.png',
#  '577D487D-6FBB-47CA-9C19-6FFE258CF2CF',
#  'hjfzbnscno.png',
#  'ootxymmdri.png',
#  '7BA4ACC9-1E1A-4C5A-BB5D-EC1D709B9374',
#  'E73FF4E0-75F9-4D8E-828E-BED8B0C136D9',
#  'D75D0E16-FC7A-4811-B7DB-8F56801700E5',
#  '7AAD9733-2DAE-411F-B07F-9C48F4241D54',
#  'zptlufvpna.png',
#  'anawxbrbkq.png',
#  '6E833384-8E84-440D-B474-7AE1EB93DE81',
#  'wzgyalbrav.png',
#  '95A92F0D-B1E4-4BCA-BC40-4223EC0F3442',
#  '1383CB7C-8720-4F0E-BB8E-6A080C90942E',
#  '855B8974-026A-4B09-A705-768E14B7D9D5',
#  'ysfhwxooce.png',
#  '1CA791AF-69F8-45CA-84BE-11E7049222E6',
#  'EDFE926A-3C79-4C3A-BF5F-2984D64D7D3C',
#  'mdtqoshzkj.png',
#  'whqhimfnlv.png',
#  'dducghzwsc.png',
#  'eoytxphcox.png',
#  'aiyyvielnk.png',
#  'opmzlkhprq.png',
#  'B91A8DA3-2C2E-48A4-9DB3-21CF41176869',
#  'ndoqrtkprk.png',
#  'AED3C3A0-C544-4278-921F-140E1703E3B8',
#  'FD8C37E2-5AA1-4B92-A5D5-1C3194E519C8',
#  'igtisrhxxg.png',
#  '857A3092-D745-4236-B4B8-C94FFCAD367A',
#  '60D6719C-4241-47BD-B4BC-AFDA1FED3F10',
#  'vbzsoabbmo.png',
#  'bqpmxwgvfz.png',
#  '3FF88F60-C892-4976-8204-6734CC8578FC',
#  'bwvekybbxo.png',
#  'ayjtcvhuwk.png',
#  'pvvbnicnvs.png',
#  'tdzwgyaugx.png',
#  '8872569F-6FF9-4902-8F35-544A0D666AAB',
#  'vaggzkkdqj.png',
#  'F3188BC7-074F-4735-BC1E-CD217DAA9C26',
#  '9FABDCAC-EB41-4AA7-A288-51F47467EE35',
#  'bciibxstmz.png',
#  '006E2378-06F7-4566-9174-F75DEE2F52BB',
#  '783076EF-768B-4628-9EE3-6224C8B08039',
#  'BF10D1E1-7DD6-4078-99C6-D3AA0321131E',
#  'zusfgewnca.png',
#  '97B5A442-4924-453E-AF23-A67F412AC1D6',
#  '55F85DF2-DC6D-408F-82B0-BCCD83C0881E',
#  'hexkaswwdu.png',
#  'mrnutcpiat.png',
#  '32C71C48-909D-4DAD-89E5-BE6A97FD6640',
#  '9133BC15-E179-4A50-A4E5-0FC2AAC4E8DD',
#  'gidxtcqtgz.png',
#  'qrtirfgpju.png',
#  'FA5DC38B-5CBD-4062-95E9-FB7A7A72129E',
#  'rmztxhmmvt.png',
#  'vjkgzqbffn.png',
#  'qmnlvghury.png',
#  'fwdfnzyvfh.png',
#  'D02EFFFD-879E-4980-9D1D-8FB41BB0683F',
#  '42E3E209-72D1-4846-9788-3F3241B754A3',
#  'nmxuosmnnw.png',
#  'yiqdcrcbep.png',
#  '8BE9C1FD-57C0-47BE-84BE-9E8135272276',
#  'fzsynskthg.png',
#  '93E63E5F-AE04-4A7D-B790-1A37668149C2',
#  'hcfxqisdei.png',
#  '3F2C051C-3D69-4573-A3C3-2E9B4600E8FE',
#  'FECCC37F-00A1-432A-B435-7E7019474E9E',
#  'frdssknyzz.png',
#  'mfwijsulqa.png',
#  '2A8DE197-0931-4D76-8112-3E214C4DEA78',
#  '65B400DB-35D0-4FEA-9360-33E2ACBEF795',
#  'qcbxkwzztn.png',
#  '190BBF61-582D-45B2-B7FD-83C92EBC479B',
#  'psruyvdelt.png',
#  'jdmaxpasjd.png',
#  '1E5D57AB-CD78-4D1E-8D3B-043CF5695952',
#  '0C0C116A-444B-4E9A-9781-B9DB4E8D62CE',
#  'xhlodhqgms.png',
#  'F3383FC6-4D9B-4A91-A51E-AED5052B4FA5',
#  'wtzdwbxxkz.png',
#  'F26004E4-9D34-4EBD-BD08-51A30BF58D64',
#  '60879F9D-A146-4FE5-B563-D7A67B98C56E',
#  'EFF4E32A-393D-4DE1-8869-4E8160D78E64',
#  'A4CD94BD-C1E7-40D4-A2BD-C9C6AFCCFB9E',
#  'fusbhfflir.png',
#  'zuhczrhymh.png',
#  '41AE632F-9E43-4E5F-B1C9-14981B465851',
#  'tvtmrqmblr.png',
#  'tjrpkojrvz.png',
#  '306D3411-FF9D-4454-B6B0-E710C48F166E',
#  '13F22F61-F807-4F58-BE8B-B26B73F3DEA6',
#  'ebmwwguxxv.png',
#  '2D666908-348A-41FA-A469-0FE7662C2650',
#  'nxrqhlgfqa.png',
#  'xwmvbrffgv.png',
#  'jeatimmnth.png',
#  'eruxedkurs.png',
#  '15BDCE03-DB3C-4F75-8AD2-0B376CE1529D',
#  'tlpdmewdpb.png',
#  '57CEB801-E50E-421F-89AB-5E3BD7AA10F5',
#  'FE2B2855-EBD7-4C84-9634-168C776B3E75',
#  '5BDBF42A-E2E5-4CC4-AF47-AE811C0CAC5C',
#  'npugzykbfg.png',
#  'xphpupyasm.png',
#  '86178F59-AF19-4962-970F-DF705D83335F',
#  'utonistlxu.png',
#  'mxhclrmjao.png',
#  'zgvdcwgvox.png',
#  'vyupavffwj.png',
#  'pxlhdgcexm.png',
#  'spccfxhtsz.png',
#  '37587862-F616-4FF4-BD20-252218FFA519',
#  'zgkuwyaysg.png',
#  'cnlrlykiuz.png',
#  '0A2AC5C6-0341-4110-ACCC-7B7C43B5E3F9',
#  'B1B6DF8A-336C-4B18-959F-7710EBAAFADE',
#  'dyalahjgrt.png',
#  'figvdvttyy.png',
#  'AEA3FEAA-376F-427E-A660-83777C7CDD7F',
#  'nlubworhlq.png',
#  'pyhcjiqblh.png',
#  'mznfntrbya.png',
#  'qpbnxtktuj.png',
#  '6316746C-201C-43E5-9711-9624C823ED88',
#  'sgewnvgdag.png',
#  'nqkuxjkzwm.png',
#  'fzqfnpmcze.png',
#  '360F4805-6A98-4E44-8FB7-F77E7D562F0F',
#  'ubrjhoqmst.png',
#  'gtzejqctjq.png',
#  '9FD7401E-9738-4907-918B-0CA1F1B43172',
#  'E7CAEE6F-AAF1-4C96-AB5B-18F3CEF6E888',
#  'tfvrewcqka.png',
#  'orljhsfmeq.png',
#  'epgtfmuesc.png',
#  'lmqvxfaktu.png',
#  'yvpzqwxhmg.png',
#  'E8C341E9-79D2-40B9-82A4-B1D08F8C1F08',
#  'pebtbzkekw.png',
#  '93105F45-6539-42D4-9BC4-0B710B4D3D0A',
#  'rtmhalrfuz.png',
#  '52D64B9F-9E67-431F-B589-C49CB5D55B4F',
#  '9924D5EE-3AB6-47EC-93B2-D6CDFA08E1FB',
#  'bvdrkaogqj.png',
#  'vbcnijqtns.png',
#  'F4F4A49A-BD0C-4342-89E1-B5637FADCFE5',
#  'imumflpmgq.png',
#  '2F4E501E-2436-4D48-8046-56B845530F92',
#  '396501F9-9E78-4B9C-AF60-5C5809823B70',
#  'F5D59428-8EDE-45DB-8FEE-D0148FAAD361',
#  'xhcrtywqcj.png',
#  'B7EFCD24-C549-4BFF-8932-124DA4CECA54',
#  '7C8B9EC7-B325-46D7-A73E-E4D1B5B862DF',
#  '5301FA72-0C4E-4AF5-B1CA-6C63FC92E9E2',
#  '06B1B93F-05FD-4C43-A1E4-3F2FFCBEC223',
#  'qzuivzufgs.png',
#  'E2647A2A-704F-4DAF-B22B-DBE3347F5A6F',
#  'juhefrsuxp.png',
#  '42020E28-CAEE-4D53-9A73-ADCB2EDA8A12',
#  '45C256AA-4276-4060-9C01-FFD95ED5A364',
#  'A8117D6C-B8E9-4043-BF10-324037A6AC23',
#  'oqzfldlaux.png',
#  '88C42E35-2ACE-405B-A5C8-DCCF075ECF05',
#  'tdzcfhcego.png',
#  '58024317-1486-466D-B04C-24A14C871486',
#  'splaiwafpw.png',
#  '52E16808-8097-4BC1-9A8D-8353FF005F3A',
#  'D2B95B8F-04A5-40EE-993D-9F37B5FB2597',
#  '9CDBEB4C-B306-48B9-B81C-606D0D288A81',
#  'B7DC24B6-4FAE-4B4C-8A96-DF92B2F44446',
#  'fxqaurcwcq.png',
#  '96C0A4F3-E4E8-4D2B-945E-1E0A54784DBA',
#  '6965F33B-7797-4CE8-B567-CCA8562FF31D',
#  'vhhwookeor.png',
#  '1A6EEB2A-F9CE-4642-B7DB-7B5AFFE502AA',
#  '08701F7B-0B45-4B90-9AF4-63F434DB8981',
#  'ochxbkckih.png',
#  'xnaiomjsbp.png',
#  'bpspqebtfw.png',
#  '4363FD41-2331-4F69-BE1F-A55A1CA4B7D6',
#  'bwrzawjpqf.png',
#  'detjngiiqe.png',
#  'C17F02F5-AF2F-412A-AF62-BBAC99C4A90F',
#  '43AD290E-895E-4B90-80FA-FB7C25819143',
#  'ykrjixfpxj.png',
#  '12637B59-D813-4099-B0DF-1666131A6279',
#  '0A666374-ADEE-43C5-9A06-16EC861A3681',
#  'tjrmdupfyy.png',
#  '3DED107D-375C-484D-9A97-468AA3A05027',
#  '7DEC3663-CD71-4EC0-9017-ADA43E234D55',
#  'higbkuionl.png',
#  'irtusmqyow.png',
#  'zoewujshny.png',
#  '87C5ED8A-9212-43D4-B63D-AEB6C2ABB5CE',
#  'ztxtjmmpbw.png',
#  'oznpzkpiuw.png',
#  'ivcfkndphf.png',
#  'fhrmdwhboq.png',
#  '1DAD1641-5E84-4918-A4CE-1E11032E41CA',
#  'xltatcoykv.png',
#  'seaeumeoxr.png',
#  'E17084EC-67BA-4032-8FC8-F5CF52961491',
#  'nbjptioynz.png',
#  '00190E65-75C1-499D-997B-B7DAC06E13FF',
#  'B761CA5A-E4F1-465D-BF88-6DF7410520E5',
#  'ABBA7E2A-87B5-4BB3-94BB-F55D7688A61F',
#  'BF8A7977-6824-4E22-BC00-6DF4DCDC745D',
#  'ysdzfcuwjl.png',
#  'FBD77113-0A37-4EA7-8746-F31B8DB15CC8',
#  '283E727A-FE3A-4BBF-A392-9D98DD09D8DB',
#  'CF8D7A10-1156-498F-A462-6AB80A99CB00',
#  'rqydtyiypc.png',
#  'fzviihazth.png',
#  'E50F3AEC-39E4-481F-B855-12994AFED1D2',
#  'ucsfkgpfnx.png',
#  '743A2DF6-93AA-40B7-A9C6-5005F9EC9209',
#  '16CE696D-3407-4664-B274-C1F0B1F79425',
#  'ymqottydnm.png',
#  'pjobdierig.png',
#  'biiejzsjhl.png',
#  '0F6410C4-E8AD-48C7-8480-27292AA6CDF9',
#  'C5900CCD-C63C-488D-9C2C-694A579306B5',
#  'tpnirdxlts.png',
#  'zhpnigakyd.png',
#  'pwoutkjbzd.png',
#  '9E646E1A-40E7-4E7F-BAE2-1ACBD6A70E4E',
#  'joebdqxdph.png',
#  'iyvnuedfli.png',
#  'hnrqucgjml.png',
#  'imeegdobsz.png',
#  'oijcqxewny.png',
#  'uftmaadkug.png',
#  'CC3A8F79-1D43-41D6-B93B-DBC45B0D2113',
#  'CBA109CD-B47B-49CE-9893-DAC3A218212A',
#  'gfrrjtwmti.png',
#  'E894CEA1-CD4E-4F28-AFFB-5E59586AF07A',
#  'shfwjhtoeu.png',
#  '6C7B12AC-F986-4B2B-899B-5136ED879B40',
#  'mfhepnasgq.png',
#  'qapdismetv.png',
#  'pyzhcxwfeb.png',
#  '7FD05507-8A4B-4042-911F-7778E6133AA1',
#  '7C58BC44-DBD9-4244-A802-3AAF475BEB0E',
#  'ojlnfyyzns.png',
#  '9BECE994-4E5A-4915-A665-A4F59D8CA370',
#  '6898A064-9C01-4047-BE9F-35CC983740BF',
#  'gpukofzsox.png',
#  'mlenuchatn.png',
#  'ibzldbpvkg.png',
#  '7AFE9EA9-7F68-4ABB-808F-A642F79F428F',
#  'F448AA60-C104-46C4-AE07-689A0AF78AD9',
#  '02F4C853-4FCA-4D3C-A8C9-C7CD4963E098',
#  'BCDF3774-55FC-4441-B076-3EB4EF3C78E9',
#  'F24AAD9B-DDC5-4597-8B44-F8434779EDF6',
#  'wfsuqvyoyp.png',
#  'aexxpnwqcm.png',
#  '744DAEEF-4E0D-426D-9120-919698FECB7B',
#  '48328DFE-1D6C-4483-8AF5-E67DC33549D8',
#  '3B7F716C-1606-4C30-BA1C-C1FD52B6E5AA',
#  '6902269C-89DD-413F-B9A0-95ABEA759950',
#  'gfchvkrgii.png',
#  'hscvtadghd.png',
#  'vpeqidtsgi.png',
#  'EC068315-9F77-4DED-8C44-99CE7A822D28',
#  'ishrtxgfzt.png',
#  'yfpmdxlepv.png',
#  '95ACFEA8-FE8E-48CC-858E-F9C69FCDAB21',
#  'E1CAAC95-E5CD-4D2C-A38A-F8B357E9A329',
#  '7961CE86-1D52-46C3-9269-3FD5273AA47A',
#  'vohdbxnshm.png',
#  '1D3739C1-5D74-4A4E-80CA-6088792525B1',
#  'hbtmqkhnrs.png',
#  'D1EDB46D-91FA-4AFC-B98B-B665273ECB0D',
#  'C615D8C1-6051-4AA2-A06B-B8B4306F9535',
#  'EB5C60F6-4F6A-4C13-A163-A69A71D09F79',
#  'afokemxeja.png',
#  'ukbfcucdpk.png',
#  'rlqmfmgdwc.png',
#  'tafecspkzb.png',
#  '101CD519-B001-4804-802D-2D1DC623AAF9',
#  'CCD2B25B-309F-43CD-A521-24B337783656',
#  'EF7C92F5-22BA-48B9-B16F-37CFC81EA8A7',
#  '34A0E724-9E7D-40C9-8E5B-5B6447068197',
#  'mnedshvvdk.png',
#  'D15A7372-6A28-4E65-BAB6-B9CA9E9121AF',
#  '09B1576F-D928-49FB-9901-5270D32F5082',
#  '148CA0E1-B676-4C02-AC10-DC13605C4E3D',
#  'gsjvggwthg.png',
#  '705D64AE-9012-4C61-854C-8AD630D818D2',
#  'jpgkrtcciw.png',
#  '9A029C72-D923-4EC8-B64D-DB4C8E8F349A',
#  'BC81EC3A-A2C3-4889-8482-ACA6888A70FD',
#  'B847CA33-D043-46F4-B4EB-46BD8B58A64E',
#  'pusgxroajb.png',
#  '7E6B9422-DAE0-4EC4-A1C2-82A9CDC81B09',
#  'AC51A09A-5ECC-4F74-A72D-55DA066D2D11',
#  'F02784EE-4E81-4587-BD0B-4AF7771A60DB',
#  'wfljreqehc.png',
#  'rtmnlqwulm.png',
#  'jcsyabbwvh.png',
#  'zfgixqzlbk.png',
#  '5BFAEDDF-E093-4AAD-A3D0-2CE95EEF0A8E',
#  'gkpxhbsgpo.png',
#  'luhsngyaay.png',
#  'sogfydvysj.png',
#  'fjigtpejmy.png',
#  '8214EB97-A23E-43B3-9156-18714C3F73D1',
#  '94188227-8FA4-4A94-A9BC-C956FD8FD6E3',
#  'rxvighsibo.png',
#  '8096FB63-9353-467D-A7A2-5BF8E38D5EDE',
#  '169E801B-0FF5-46C0-8ACB-1F1911E63D87',
#  'fwlyjuvcuo.png',
#  'B4F954A5-65E7-472A-B197-9642AEB777D8',
#  '7E5C6FAA-4453-4F8D-AA0E-CFACEB9A26E9',
#  'kqllvsvmub.png',
#  '8F71220E-87BA-4C10-B65A-640054C8EA1C',
#  '319EDA0F-E4B3-447D-906D-CD3A8A2ACD7D',
#  '551191D7-FFA1-4543-89C1-25FD312A55CD',
#  'B1E31053-3576-488F-9948-ADFA0D8CE169',
#  '865C8D78-769E-4560-A1D6-1247BFDD678B',
#  'nforuyuqdr.png',
#  'dvavgdzcpm.png',
#  '3286E45C-0D55-42BA-9831-EEAF7131C53B',
#  '49B8EB88-E494-4196-955D-36022DF413C4',
#  'dmxkzviakc.png',
#  'F9A55EA2-9D48-4396-B743-976047F37C8C',
#  'orurigyptr.png',
#  'theqaneqra.png',
#  '2D6B741B-B9AA-408A-8993-6845A1A021EC',
#  'aedguspqtf.png',
#  'jxvadesjab.png',
#  'zzhmrzearx.png',
#  'E0811E1A-93B5-46D6-A4CF-FEE342453D6F',
#  'alzpeqelxj.png',
#  'pilywzrfmo.png',
#  '499B47A5-26DF-43C3-BC53-2AF219A605B7',
#  'B08280CB-2408-4007-9A1F-DE8B54734B7F',
#  'mhcvjykfjj.png',
#  'pkqyytepix.png',
#  'lercbcgrex.png',
#  'cplbnzkjoy.png',
#  'ztikjgrmdh.png',
#  'qiozlcuptq.png',
#  '4E5D30D7-D7FE-4EEA-BD5D-B4D983C4481E',
#  'aoikzyhvcc.png',
#  '1A64F2E8-9535-4962-A41B-2259F8FBFA0B',
#  '3EAA404C-87DF-4413-9A64-506FF510E0E1',
#  '9B36931C-9A1A-4F40-A976-CEDA24005492',
#  '03A7EA4C-437B-4D55-BC9B-0335DDD5330C',
#  'xhriucwfks.png',
#  'rfktncgcbc.png',
#  '31831D8D-FA4B-40D4-8A4D-968C6D8E6CDE',
#  'C72A3EBD-4F01-4EA4-974C-C7F982FE9030',
#  'qvvrflqdmj.png',
#  '2FC5D0F1-A005-404E-AF9A-D7C3BE450A0A',
#  '61E783AE-00C9-4B5D-AACB-764DB141B529',
#  'svmcrhpuew.png',
#  'EA92C0C2-8471-4B83-B7C1-6F1D4F9EA197',
#  'wttcvoutgs.png',
#  'gtlvoipujx.png',
#  'gpzevyxhdl.png',
#  'D08715EE-8C13-4685-9554-87E1D6E0ED05',
#  'bojfzdyvgg.png',
#  'esbvetjmac.png',
#  'gfksweejdh.png',
#  '48143553-73DE-48DD-A723-A0E1936FBD80',
#  'A4F8B575-6D13-4F74-A584-F099D3B8DC15',
#  'orhgwgkqkj.png',
#  'ldepifiwqp.png',
#  'AF515398-1157-4BD0-849B-A7C55A0EBA94',
#  '268ABB4E-C858-4D7D-8AD1-5E8C83AE7273',
#  '85F843D2-92F5-420B-84F6-6A2A406FE4E6',
#  '954C0204-D424-499E-94BB-144E2F39760A',
#  '4FA173BA-059C-49A3-A8CA-86E1E0BCB39F',
#  'uxmhldfjxg.png',
#  '8BCDE9AD-79B7-48AB-AD6D-FE251AD96C9C',
#  '3F5B7BA9-FF5D-4EBB-89E1-D48406A68658',
#  'rpuvpnvrsn.png',
#  'F7570DB8-2FD4-4866-8C03-DB6E4782C194',
#  'CC0A9D26-078E-4333-A41E-F298A942383F',
#  '8EDBD664-00E0-4C27-9330-9D6740D655CA',
#  'fxxbrxedpy.png',
#  '4A39C01A-BA63-468A-9318-9FBB81F3CD27',
#  'ucxuwufvyt.png',
#  'zenibveblt.png',
#  'ewbwurhrdt.png',
#  '844420EF-7543-484B-AF56-F91FFC08DBF2',
#  'E8F9E74C-473B-486C-AFE3-9F23E7F9D61A',
#  'kderhoccjr.png',
#  'E9C8FFE3-63BC-4DDE-ADBA-70FE50AA8E46',
#  'A36D3FB0-D5A2-4580-9326-CD86E9B61870',
#  'F828E492-1462-4DBD-A082-8174FC1C3480',
#  '53FAD446-033F-49A2-95BF-7A3573248CFB',
#  '7A4BD7DC-5BD3-4928-B57F-CE7C86E32DAE',
#  'klhocianlf.png',
#  'imtvubopqt.png',
#  '89D679AA-5E14-4C79-8685-983055173BE1',
#  'EFDD5439-CEFE-4C00-8B56-231575442177',
#  'lybdixwhaq.png',
#  '6A41164C-9214-497B-BF52-479565D97D51',
#  'yzboniwvxs.png',
#  'A2588BF6-59F9-4393-B76D-B9C07253306B',
#  '56FE015E-03CB-43A8-A4D1-C89D51C240A8',
#  '37178C9C-97CF-403B-A546-F8D8323035DF',
#  'nwmtnhmuqm.png',
#  'zwxdfiells.png',
#  'lkgizxjksm.png',
#  '8F129EAF-41D9-4E91-9330-E99B97EC81F6',
#  '96548FE3-C8C0-4799-A951-A0457EC1537A',
#  'D26D3C8F-6E7F-4396-BF8E-38EA126C51D6',
#  'A2B75950-F9C2-4712-B558-DADDE74E5C72',
#  '0D95B25B-1513-40CF-9EC6-14D523B68866',
#  'ydmmfhwnlu.png',
#  '83558D15-780C-4654-90A3-2A5A6B972533',
#  '56FBB469-4102-499F-9905-2B1EA0C23ED6',
#  '6DB316C3-FA60-406D-93F9-A9EEC9750CFB',
#  'CD3D0040-27E9-4DE6-A356-E6D401144ED2',
#  'yhnsxnulrz.png',
#  'ozygvrmsqd.png',
#  'zhghtptbnc.png',
#  'bklfjavrhm.png',
#  'pupfyjdtzn.png',
#  'wdtqheuklz.png',
#  'F2CD4804-F1CE-4EE5-B4EC-04E58E7E73B1',
#  'ctbzgclmnn.png',
#  'ifloahtspr.png',
#  'djujnlmzmb.png',
#  'ddqlzhblmz.png',
#  'DDFDD88D-AE45-4CB3-B367-982CCF13E6AF',
#  '89F8D239-4785-4762-A107-632596D770E7',
#  '8F2FEB29-EE7F-4A36-ADB6-E448E8B8FC8D',
#  'D808A1CD-765F-4397-8B1B-96826FE4585B',
#  'qaxvgkqtnu.png',
#  'wdmoxacaqo.png',
#  '52F8637C-E145-47AF-A35B-E038A5FC0FE7',
#  'vsntzapazm.png',
#  'wvwipwlwyp.png',
#  '29908902-B9D3-4C22-9578-24B8634D3D13',
#  'dirgmehjmv.png',
#  'oosnrauxyl.png',
#  'bhwlhzgece.png',
#  'DEF95082-E798-4943-8E49-EA81ED501987',
#  '315BDD20-7B7F-4A06-B8EF-AEA0479590ED',
#  'D12E2A55-1A9C-4275-B8AB-B266054E549B',
#  '443B0AE9-B523-47F2-8EEE-1FAD7CB873D4',
#  '4D327308-D2E7-4CAA-86C4-280F55AD0D74',
#  'D2F621DF-8BBF-418E-BDF3-21EA2756609B',
#  'svabqmdgxc.png',
#  'ovruqdqzym.png',
#  'E1794E42-88DF-4D49-A311-2D9B790A9EF2',
#  '7A1C9763-4FD9-4BFD-BB04-2074AA5BD60C',
#  'yazcvadjkd.png',
#  'ggrmgncssi.png',
#  'kctovpwtpy.png',
#  'boclinkaig.png',
#  'tztuoappeo.png',
#  'buoemyalof.png',
#  'fbzdrxuymk.png',
#  'CB68A35D-AFC4-4582-816F-B22B001EDC66',
#  '1CFD66D1-0FD5-4484-A08B-7AD919895A96',
#  '683987D4-6CCF-4E4A-9A0E-28D098A594AD',
#  'ijgoufdxui.png',
#  'oxqihqctrx.png',
#  'qojipecqye.png',
#  'DDA4E11D-570F-442C-B53C-8A05F392521C',
#  'supenuwhne.png',
#  'CAD3C4A1-1FA9-4B3D-B36E-C45A34FCD8FD',
#  'mwfxrvvtyo.png',
#  '17AFF1A9-9D72-43FB-A66C-1822E5D125D4',
#  'E0E97D36-3004-4F9A-9A14-16ABA05C8C54',
#  'B50621B8-5E04-4119-BD2F-D6485424A5BA',
#  'CCB39A6A-B760-48C7-A283-494A6C9F1079',
#  'CEA2C13C-0A37-44B9-B8E2-54905C8A59AE',
#  'clomoxfjik.png',
#  'daurnkanae.png',
#  'syrjacnqub.png',
#  'zmbxrfpmna.png',
#  '8281DC2A-0FB4-49D1-AD42-E216619E2F75',
#  'aaqfukiwoc.png',
#  '88BCF1D7-88DE-47FF-9365-4665013F1E42',
#  'hufudsttls.png',
#  'zgvzuavfqt.png',
#  'FE6038BC-6244-4E7C-8478-10A7842BC810',
#  'A52A0759-00F6-4DF7-8C20-C426D045F624',
#  '239F63E5-8256-4C6E-A6AE-2B67881F49E3',
#  '2464B6AD-51AE-4D10-A4AF-6237A2290927',
#  'DC31D336-7C4B-4103-B283-836A141D881D',
#  'nixnrkvomy.png',
#  '30E49D04-1192-4CCC-9F85-D44129BC46D9',
#  'gpsyxizjsh.png',
#  'xonnypazzo.png',
#  '01B61B42-1A7B-4560-A713-9F6C8483A836',
#  '8BFE3A88-575B-44D2-B0F9-9DF763AA1C3D',
#  'DD96552A-D711-4F18-A11C-92BA1E54CC60',
#  'A4539214-2D78-4219-A552-B29E63DD5796',
#  '8FBF77A6-54F5-49A6-A4CD-1958E149EE79',
#  'zxvgdasvtn.png',
#  'jhqcpbmnun.png',
#  'EA0502AE-2C66-41B1-93A5-57D9D7BAE55D',
#  '8CA2EA3F-AC9A-430D-8744-1E3E37E4DA58',
#  'zvlweflraq.png',
#  'gygisyeqbe.png',
#  'hihbeiemgr.png',
#  '5CF89F00-A898-4BB6-B42A-06CC7EBD3114',
#  'pmietbebmc.png',
#  'xzfrxoznym.png',
#  'DEAD09D9-6ADC-4402-B62B-5FE5F0082EA7',
#  'qpohqmsrcr.png',
#  'gknpywnzob.png',
#  '1E7F290E-CBF4-4281-8E08-4831EB14BB1C',
#  'wfqurdzynt.png',
#  'egkjdwzhsm.png',
#  '9827298B-CEA8-4673-8FAD-969E6A0443E2',
#  'D3B0A6DB-3781-457F-B517-31301DAA50D1',
#  'C5352837-E41B-4AE2-82FB-450C5514D4E2',
#  '18A44723-4A95-47C3-8621-665AB9F9B0DF',
#  'pqqawghjrr.png',
#  'vaaprnknjq.png',
#  'clihvndjsb.png',
#  '031938D3-505F-42DC-9CA2-74F5B2A9C6D4',
#  'dizyexnpue.png',
#  '9ABB3980-6026-420D-90EF-776EDE1776E5',
#  'CEBE8F43-2D19-4333-B2E7-BB28305A5D7B',
#  'whkoqbysrc.png',
#  '0BE8596C-D7C2-4A83-AB7F-0DF692A11621',
#  'B65F08FB-4D5C-40B4-8E90-112FE50F3683',
#  '88EDCE81-F99D-4789-A50F-8B770A9A0F11',
#  'wlucfhzxxw.png',
#  'D95AF325-A8C5-4952-960B-C119B8FECF5B',
#  '8EA8955A-644B-4C03-BDAB-55C0ADE246FE',
#  'encmbdsspj.png',
#  '2D1E8372-17DB-4C86-A70C-9058A73B348B',
#  'zczpavkgge.png',
#  'yyjiblxiob.png',
#  'yizzmrpwde.png',
#  'ccidxkbpvg.png',
#  'rxjpqpidlq.png',
#  'ynpkurunyl.png',
#  'gikvvyqlft.png',
#  'D5DEE6F8-93BA-473F-BCC3-A7D2F77E95D4',
#  'F54FD493-BAE0-4A07-9755-B359533E3DE7',
#  'kxlwatxyks.png',
#  '88DB0698-5B45-4264-9539-1BA0BADB64B0',
#  '83980580-BE5D-48DA-B180-37166967E339',
#  '4B6FAAB0-DCF6-4E38-B1A6-607BF68F08DF',
#  'hypqmjgzfz.png',
#  '8D07EE59-C240-4799-9908-E7737CF22D25',
#  'txylbfayxy.png',
#  'FC9EDB6E-21D7-4F1B-A7FA-24F4C0179E8F',
#  '3609AEA3-58A8-49BF-A709-118A3D640A91',
#  'uakhhnglfc.png',
#  'nopjjgrcjn.png',
#  'mgzltjkdvr.png',
#  'fppqfkdpft.png',
#  'qjfccjxwcl.png',
#  '10CE169E-50ED-4BD3-812D-D601698C5BD5',
#  'veuccwdpgn.png',
#  'rnfccsiqdy.png',
#  'timcutkual.png',
#  'ihwrbzgfer.png',
#  '79B84331-4DB2-4A2D-BC36-550F9939191B',
#  '9D46E625-4256-4AC2-A70E-5008444EBEC0',
#  '9F5946A7-0D6A-4208-96C4-948F71AF02ED',
#  '85F8AE98-B797-493C-940E-7FA1407E85AF',
#  'B5598336-B4F1-4153-A292-2479B024D105',
#  'itfmvyfzzu.png',
#  '44642420-D429-4DD8-9F11-595F6201A81F',
#  'skecqdnyja.png',
#  '1E04824A-FD72-430D-ABA7-D9470E6FE638',
#  'mhtphwsfgg.png',
#  'dfxcuwerrl.png',
#  '3A300410-D077-4C28-AC92-BDC7F65DE467',
#  'osgnpaowcd.png',
#  'C3452C8E-4261-4676-A203-C60E7391AF1D',
#  'ncknlwxcug.png',
#  'A457DC5D-1D0C-480D-895C-C48831D81613',
#  'E25B42CB-484F-49C6-A081-FFBBFAC921F0',
#  'E4A7AA07-F4F9-4E8C-A985-0B9115FBB8A6',
#  '0A620AFD-48A0-4094-BE01-EAB29815DEE6',
#  'iexgdghwwx.png',
#  'bailghycuo.png',
#  'tsfpkdprbr.png',
#  '8AA1B7F8-DCF4-4A79-B380-9D9ADDC65659',
#  '945F78CC-D91E-4928-8BC5-A7FAAE625588',
#  'cltqqneofn.png',
#  'bmzpwvnryc.png',
#  'akgilnczoz.png',
#  '77DCAA52-E70F-47D0-B38A-A1F834830D80',
#  'dujrwryzvi.png',
#  '69943664-B128-48E6-8BA0-D1CA64122BA1',
#  'tvbzjkxqsc.png',
#  'rlcbglsufo.png',
#  'dboexrhbgj.png',
#  'C7F7B787-A8E9-49C1-8AF3-278C4D0B1B5A',
#  'F9662B57-8097-4009-89C2-95A57070E5DB',
#  ...}

# %%
set(alldb3['phone'])
# Out:
# {'HUAWEI CLT-L29',
#  'HUAWEI ELE-L29',
#  'HUAWEI FLA-LX2',
#  'HUAWEI JAT-L29',
#  'HUAWEI JKM-LX2',
#  'HUAWEI LDN-LX2',
#  'HUAWEI LYA-L29',
#  'HUAWEI MAR-AL00',
#  'HUAWEI MRD-LX1',
#  'HUAWEI PPA-LX2',
#  'HUAWEI SHT-AL09',
#  'HUAWEI STK-L22',
#  'HUAWEI VOG-L29',
#  'HUAWEI YAL-L21',
#  'INFINIX MOBILITY LIMITED Infinix X657B',
#  'INFINIX MOBILITY LIMITED Infinix X657C',
#  'INFINIX MOBILITY LIMITED Infinix X688C',
#  'INFINIX MOBILITY LIMITED Infinix X698',
#  'LAVA LH9930',
#  'OPPO A1601',
#  'OPPO A37f',
#  'OPPO A37fw',
#  'OPPO CPH1819',
#  'OPPO CPH1821',
#  'OPPO CPH1823',
#  'OPPO CPH1907',
#  'OPPO CPH1911',
#  'OPPO CPH1931',
#  'OPPO CPH1933',
#  'OPPO CPH1937',
#  'OPPO CPH1969',
#  'OPPO CPH1989',
#  'OPPO CPH2001',
#  'OPPO CPH2015',
#  'OPPO CPH2065',
#  'OPPO CPH2083',
#  'OPPO CPH2113',
#  'OPPO CPH2121',
#  'OPPO CPH2127',
#  'OPPO CPH2145',
#  'OPPO CPH2159',
#  'OPPO CPH2185',
#  'OPPO CPH2197',
#  'OPPO CPH2203',
#  'OPPO CPH2219',
#  'OPPO CPH2237',
#  'OPPO CPH2239',
#  'OPPO CPH2269',
#  'OPPO CPH2293',
#  'OPPO CPH2343',
#  'Realme RMX1851',
#  'Realme RMX1911',
#  'Realme RMX1925',
#  'Realme RMX1941',
#  'Realme RMX1971',
#  'Realme RMX2001',
#  'Realme RMX2030',
#  'Realme RMX2040',
#  'Realme RMX2061',
#  'Realme RMX2111',
#  'Realme RMX2170',
#  'Realme RMX3085',
#  'Realme RMX3191',
#  'Realme RMX3231',
#  'Realme RMX3241',
#  'Samsung SM-A022F',
#  'Samsung SM-A025F',
#  'Samsung SM-A035F',
#  'Samsung SM-A037F',
#  'Samsung SM-A105G',
#  'Samsung SM-A107F',
#  'Samsung SM-A115F',
#  'Samsung SM-A125F',
#  'Samsung SM-A127F',
#  'Samsung SM-A205F',
#  'Samsung SM-A207F',
#  'Samsung SM-A217F',
#  'Samsung SM-A226B',
#  'Samsung SM-A305F',
#  'Samsung SM-A307GN',
#  'Samsung SM-A315G',
#  'Samsung SM-A326B',
#  'Samsung SM-A426B',
#  'Samsung SM-A505F',
#  'Samsung SM-A507FN',
#  'Samsung SM-A515F',
#  'Samsung SM-A525F',
#  'Samsung SM-A526B',
#  'Samsung SM-A528B',
#  'Samsung SM-A530F',
#  'Samsung SM-A605G',
#  'Samsung SM-A705F',
#  'Samsung SM-A715F',
#  'Samsung SM-A730F',
#  'Samsung SM-A750GN',
#  'Samsung SM-A805F',
#  'Samsung SM-G780F',
#  'Samsung SM-G781B',
#  'Samsung SM-G955F',
#  'Samsung SM-G965F',
#  'Samsung SM-G965U',
#  'Samsung SM-G973F',
#  'Samsung SM-G985F',
#  'Samsung SM-G991B',
#  'Samsung SM-G998B',
#  'Samsung SM-J400F',
#  'Samsung SM-J415F',
#  'Samsung SM-J610F',
#  'Samsung SM-M022F',
#  'Samsung SM-M315F',
#  'Samsung SM-N770F',
#  'Samsung SM-N950F',
#  'Samsung SM-N960F',
#  'Samsung SM-N970F',
#  'Samsung SM-N975F',
#  'Samsung SM-P610',
#  'Samsung SM-S908E',
#  'Samsung SM-T295',
#  'Samsung SM-T500',
#  'Vivo 1806',
#  'Vivo 1818',
#  'Vivo 1819',
#  'Vivo 1820',
#  'Vivo 1901',
#  'Vivo 1902',
#  'Vivo 1904',
#  'Vivo 1906',
#  'Vivo 1915',
#  'Vivo 1920',
#  'Vivo 1933',
#  'Vivo 1935',
#  'Vivo 1938',
#  'Vivo 2006',
#  'Vivo 2015',
#  'Vivo 2018',
#  'Vivo V2025',
#  'Vivo V2026',
#  'Vivo V2027',
#  'Vivo V2036',
#  'Vivo V2038',
#  'Vivo V2041',
#  'Vivo V2043',
#  'Vivo V2050',
#  'Vivo V2102',
#  'Vivo V2109',
#  'Vivo V2111',
#  'Vivo V2124',
#  'Vivo V2126',
#  'Vivo V2130',
#  'Vivo V2131',
#  'WIKO W-K211-TH',
#  'Xiaomi 21061110AG',
#  'Xiaomi 21061119AG',
#  'Xiaomi 2107113SG',
#  'Xiaomi 21081111RG',
#  'Xiaomi 2109119DG',
#  'Xiaomi M2003J15SC',
#  'Xiaomi M2004J19C',
#  'Xiaomi M2006C3LG',
#  'Xiaomi M2007J3SY',
#  'Xiaomi M2010J19SG',
#  'Xiaomi M2012K11AG',
#  'Xiaomi M2101K9AG',
#  'Xiaomi M2102J20SG',
#  'Xiaomi MI 8',
#  'Xiaomi Redmi 8A',
#  'Xiaomi Redmi Note 9S',
#  'iPad11,4',
#  'iPad11,6',
#  'iPad11,7',
#  'iPad12,1',
#  'iPad13,1',
#  'iPad13,2',
#  'iPad13,4',
#  'iPad13,6',
#  'iPad14,2',
#  'iPad7,11',
#  'iPad7,12',
#  'iPad7,4',
#  'iPad7,5',
#  'iPhone10,2',
#  'iPhone10,3',
#  'iPhone10,4',
#  'iPhone10,5',
#  'iPhone10,6',
#  'iPhone11,2',
#  'iPhone11,6',
#  'iPhone11,8',
#  'iPhone12,1',
#  'iPhone12,3',
#  'iPhone12,5',
#  'iPhone12,8',
#  'iPhone13',
#  'iPhone13,1',
#  'iPhone13,2',
#  'iPhone13,3',
#  'iPhone13,4',
#  'iPhone14,2',
#  'iPhone14,3',
#  'iPhone14,5',
#  'iPhone8,1',
#  'iPhone8,2',
#  'iPhone9,1',
#  'iPhone9,2',
#  'iPhone9,3',
#  'iPhone9,4'}

# %%
alldb['phone'].replace({'HUAWEI CLT-L29':'','HUAWEI ELE-L29','HUAWEI FLA-LX2','HUAWEI JAT-L29', 'HUAWEI JKM-LX2','HUAWEI LDN-LX2',
                        'HUAWEI LYA-L29','HUAWEI MAR-AL00','HUAWEI MRD-LX1', 'HUAWEI PPA-LX2','HUAWEI SHT-AL09','HUAWEI STK-L22',
                        'HUAWEI VOG-L29','HUAWEI YAL-L21',

# %%
set(alldb3['ov'])
# Out:
# {'0',
#  '1',
#  '2',
#  '3',
#  '4',
#  'ขุ่น',
#  'ติดเชื้อ +2 ',
#  'ปกติ (เหลืองใส)',
#  'มีตะกอน',
#  'มีเม็ดเลือดแดง',
#  'สีน้ำนม',
#  'สีฟ้า หรือน้ำเงิน',
#  'ใสเป็นน้ำเปล่า'}
